# %% [markdown]
# # DYCD Programs and Demography

# %% [markdown]
# # Background

# %% [markdown]
# Research question: Are DYCD program sites correlated with demographic characteristics?
# DYCD: New York City Department of Youth and Community Development
#
# Variables
# - Number DYCD 2019 program sites per zip code
# - 2019 NY Demographic statistics per zip code
#
# Goals
# - Compute correlations between demographic characteristics and number of DYCD 2019 program sites per zip code
#   Demographic characteristics: population count, gender, ethnicity, US citizens, public assistance
# - Create data visualisation of the results

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# ## Source data

# %%
demostats = pd.read_csv("Demographicstats.csv")
demostats
# Out:
#      JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 0                10001                  44            22            0.50
# 1                10002                  35            19            0.54
# 2                10003                   1             1            1.00
# 3                10004                   0             0            0.00
# 4                10005                   2             2            1.00
# ..                 ...                 ...           ...             ...
# 231              12788                  83            39            0.47
# 232              12789                 272           115            0.42
# 233              13731                  17             2            0.12
# 234              16091                   0             0            0.00
# 235              20459                   0             0            0.00
#
#      COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# ...

# %%
progsites = pd.read_csv("Programsites.csv")
progsites
# Out:
#             Date      Service Category Program Area          Program Type  \
# 0     06/01/2019  Afterschool Programs      Compass    COMPASS Elementary
# 1     06/01/2019  Afterschool Programs      Compass    COMPASS Elementary
# 2     06/01/2019  Afterschool Programs       Beacon                Beacon
# 3     06/01/2019  Afterschool Programs      Compass    COMPASS Elementary
# 4     06/01/2019    Community Services      Compass    COMPASS Elementary
# ...          ...                   ...          ...                   ...
# 6024  06/01/2019    Immigrant Services         CSBG               Seniors
# 6025  06/01/2019  Jobs and Internships         SYEP             NYCHA MAP
# 6026  06/01/2019    Immigrant Services         CSBG               Seniors
# 6027  06/01/2019    Immigrant Services         CSBG  NDA Healthy Families
# 6028  06/01/2019  Jobs and Internships         SYEP      Older Youth (OY)
#
#                                                Provider  \
# ...
