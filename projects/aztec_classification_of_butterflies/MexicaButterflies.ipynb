# %% [markdown]
# # The butterflies of the Florentine Codex

# %% [markdown]
# ### Creating DataFrame

# %%
import pandas as pd
import re

# %% [markdown]
# ### Sentences with spaCy

# %%
import spacy

# %%
papalotl = open('papalotl.txt')
butterflies = papalotl.read()

# %%
from spacy.lang.en import English

raw_text = butterflies
nlp = English()
nlp.add_pipe(nlp.create_pipe('sentencizer'))
doc = nlp(raw_text)
sentences = [sent.string.strip() for sent in doc.sents]

# %%
sentences[:10]
# Out:
# ['Whatever the kind of butterfly, it is long and straight, the abdomen is slender, the neck is constricted.',
#  'lt is fuzzy, like fat; winged.',
#  'Its wings are twofold.',
#  'It has arms, it has legs, it has antennae.',
#  'lt is a flyer, a constant flyer, a flutterer, a sucker of the different flowers, and a sucker of liquid.',
#  'It is fuzzy.',
#  'It trembles, it beats its wings together, it constantly flies.',
#  'It sucks, it sucks liquid.',
#  'It is not solid.',
#  'There are many kinds of butterflies.']

# %%
# Get rid of newlines
sentences = [item.replace('\n', " ") for item in sentences]

# %%
df = pd.DataFrame(sentences) 
df.columns = ['BUTTERFLY']
df[:10]
# Out:
#                                            BUTTERFLY
# 0  Whatever the kind of butterfly, it is long and...
# 1                     lt is fuzzy, like fat; winged.
# 2                             Its wings are twofold.
# 3         It has arms, it has legs, it has antennae.
# 4  lt is a flyer, a constant flyer, a flutterer, ...
# 5                                       It is fuzzy.
# 6  It trembles, it beats its wings together, it c...
# 7                         It sucks, it sucks liquid.
# 8                                   It is not solid.
# 9               There are many kinds of butterflies.

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(butterflies)

# %%
for token in doc:
    print(token, token.pos_, token.dep_, token.lemma_)
# Out:
# Whatever PRON advcl whatever
# the DET det the
# kind NOUN nsubj kind
# of ADP prep of
# butterfly NOUN pobj butterfly
# , PUNCT punct ,
# it PRON nsubj -PRON-
# is AUX ccomp be
# long ADJ acomp long
# and CCONJ cc and
# straight ADJ conj straight
# , PUNCT punct ,
# the DET det the
# abdomen NOUN nsubj abdomen
# is AUX ccomp be
# slender ADJ acomp slender
# , PUNCT punct ,
# the DET det the
# neck NOUN nsubjpass neck
# is AUX auxpass be
# constricted VERB ROOT constrict
# . PUNCT punct .
# lt PROPN nsubj lt
# is AUX ccomp be
# fuzzy ADJ acomp fuzzy
# , PUNCT punct ,
# like SCONJ prep like
# fat NOUN pobj fat
# ; PUNCT punct ;
# winged VERB ROOT wing
# . PUNCT punct .
# Its PRON poss -PRON-
# wings NOUN nsubj wing
# are AUX ROOT be
# twofold ADJ acomp twofold
# . PUNCT punct .
# It PRON nsubj -PRON-
# has AUX ccomp have
# arms NOUN dobj arm
# , PUNCT punct ,
# it PRON nsubj -PRON-
# has AUX ccomp have
# legs NOUN dobj leg
# , PUNCT punct ,
# it PRON nsubj -PRON-
# has AUX ROOT have
# antennae NOUN dobj antennae
# . PUNCT punct .
# lt PROPN nsubj lt
# is AUX ROOT be
# a DET det a
# flyer NOUN attr flyer
# , PUNCT punct ,
# a DET det a
# constant ADJ amod constant
# flyer NOUN appos flyer
# , PUNCT punct ,
# a DET det a
# flutterer NOUN conj flutterer
# , PUNCT punct ,
# a DET det a
# sucker NOUN appos sucker
# of ADP prep of
# the DET det the
# different ADJ amod different
# flowers NOUN pobj flower
# , PUNCT punct ,
# and CCONJ cc and
# a DET det a
# sucker NOUN conj sucker
# of ADP prep of
# liquid NOUN pobj liquid
# . PUNCT punct .
# It PRON nsubj -PRON-
# is AUX ROOT be
# fuzzy ADJ acomp fuzzy
# . PUNCT punct .
# It PRON nsubj -PRON-
# trembles VERB ccomp tremble
# , PUNCT punct ,
# it PRON nsubj -PRON-
# beats VERB ccomp beat
# its PRON poss -PRON-
# wings NOUN dobj wing
# together ADV advmod together
# , PUNCT punct ,
# it PRON nsubj -PRON-
# constantly ADV advmod constantly
# flies VERB ROOT fly
# . PUNCT punct .
# It PRON nsubj -PRON-
# sucks VERB ccomp suck
# , PUNCT punct ,
# it PRON nsubj -PRON-
# sucks VERB ROOT suck
# liquid ADV advmod liquid
# . PUNCT punct .
# It PRON nsubj -PRON-
# is AUX ROOT be
# not PART neg not
# solid ADJ acomp solid
# . PUNCT punct .
# There PRON expl there
# are AUX ROOT be
# many ADJ amod many
# kinds NOUN attr kind
# of ADP prep of
# butterflies NOUN pobj butterfly
# . PUNCT punct .
#
#
#  SPACE
#
#
# XICALPAPALOTL PROPN ROOT XICALPAPALOTL
# OR CCONJ cc or
# XICALTECONPAPALOTL PROPN conj XICALTECONPAPALOTL
# . PUNCT punct .
# OR CCONJ cc or
# XICALTECON PROPN ROOT XICALTECON
#
#  SPACE
#
# It PRON nsubj -PRON-
# is AUX ROOT be
# somewhat ADV advmod somewhat
# large ADJ acomp large
# . PUNCT punct .
# Its PRON poss -PRON-
# name NOUN nsubj name
# comes VERB ROOT come
# from ADP prep from
# xicalli PROPN pobj xicalli
# [ PUNCT punct [
# gourd PROPN compound gourd
# bowl PROPN appos bowl
# ] PUNCT punct ]
# and CCONJ cc and
# papalotl PROPN nmod papalotl
# [ PUNCT punct [
# butterfly NOUN conj butterfly
# ] PUNCT punct ]
# , PUNCT punct ,
# because SCONJ mark because
# it PRON nsubj -PRON-
# is AUX advcl be
# yellow ADJ acomp yellow
# , PUNCT punct ,
# it PRON nsubj -PRON-
# is AUX ccomp be
# quite ADV advmod quite
# yellow ADJ acomp yellow
# , PUNCT punct ,
# it PRON nsubj -PRON-
# is AUX conj be
# fuzzy ADJ acomp fuzzy
# . PUNCT punct .
# And CCONJ cc and
# it PRON nsubjpass -PRON-
# is AUX auxpass be
# painted VERB ccomp paint
# with ADP prep with
# black ADJ pobj black
# ; PUNCT punct ;
# it PRON nsubjpass -PRON-
# is AUX auxpass be
# varicolored VERB ROOT varicolore
# . PUNCT punct .
# So ADV advmod so
# it PRON nsubj -PRON-
# is AUX ccomp be
# very ADV advmod very
# beautiful ADJ acomp beautiful
# , PUNCT punct ,
# coveted ADJ acomp coveted
# , PUNCT punct ,
# desirable ADJ amod desirable
# , PUNCT punct ,
# constantly ADV advmod constantly
# desirable ADJ conj desirable
# , PUNCT punct ,
# constantly ADV advmod constantly
# required VERB ROOT require
# . PUNCT punct .
# It PRON nsubj -PRON-
# is AUX ROOT be
# fragile ADJ acomp fragile
# . PUNCT punct .
# It PRON nsubj -PRON-
# yellows VERB ROOT yellow
# , PUNCT punct ,
# it PRON nsubj -PRON-
# becomcs VERB npadvmod becomcs
# painted VERB ccomp paint
# , PUNCT punct ,
# it PRON nsubj -PRON-
# becomes VERB conj become
# varicolored VERB acomp varicolore
# . PUNCT punct .
# It PRON nsubj -PRON-
# breeds VERB ccomp breed
# , PUNCT punct ,
# it PRON nsubj -PRON-
# becomes VERB parataxis become
# firm ADJ acomp firm
# , PUNCT punct ,
# it PRON nsubj -PRON-
# develops VERB parataxis develop
# ; PUNCT punct ;
# it PRON nsubj -PRON-
# flies VERB ROOT fly
# constantly ADV advmod constantly
# . PUNCT punct .
#
#
#  SPACE
#
#
# TLILPAPALOTL NOUN ROOT tlilpapalotl
#
#  SPACE
#
# It PRON nsubj -PRON-
# is AUX ROOT be
# similar ADJ acomp similar
# to PART prep to
# - PUNCT punct -
# also ADV advmod also
# just ADV advmod just
# the DET det the
# same ADJ npadvmod same
# as SCONJ prep as
# - PUNCT punct -
# the DET det the
# xicalpapalotl NOUN pobj xicalpapalotl
# , PUNCT punct ,
# but CCONJ cc but
# black ADJ amod black
# flecked VERB conj fleck
# with ADP prep with
# white ADJ pobj white
# . PUNCT punct .
# Thus ADV advmod thus
# its PRON poss -PRON-
# wings NOUN nsubjpass wing
# are AUX auxpass be
# varicolored VERB ROOT varicolore
# . PUNCT punct .
#
#
#  SPACE
#
#
# TLECOCOZPAPALOTL PROPN ROOT TLECOCOZPAPALOTL
#
#  SPACE
#
# Its PRON poss -PRON-
# name NOUN nsubj name
# is AUX ROOT be
# also ADV advmod also
# quappachpapalotl NOUN acomp quappachpapalotl
# . PUNCT punct .
# It PRON nsubjpass -PRON-
# is AUX auxpass be
# called VERB ccomp call
# " PUNCT punct "
# fireyellow VERB oprd fireyellow
# " PUNCT punct "
# because SCONJ mark because
# it PRON nsubj -PRON-
# glows VERB advcl glow
# , PUNCT punct ,
# it PRON nsubj -PRON-
# glistens VERB ROOT glisten
# a DET det a
# little ADJ dobj little
# . PUNCT punct .
# lts NOUN compound lt
# body NOUN nsubj body
# is AUX ROOT be
# a DET det a
# little ADJ amod little
# fiery NOUN attr fiery
# , PUNCT punct ,
# but CCONJ cc but
# it PRON nsubj -PRON-
# is AUX conj be
# smoky ADJ acomp smoky
# , PUNCT punct ,
# tawny PROPN npadvmod tawny
# . PUNCT punct .
# It PRON nsubj -PRON-
# glows VERB ROOT glow
# , PUNCT punct ,
# glistens NOUN intj glisten
# , PUNCT punct ,
# glistens VERB conj glisten
# constantly ADV advmod constantly
# . PUNCT punct .
# It PRON nsubj -PRON-
# is AUX ROOT be
# tawny ADJ attr tawny
# , PUNCT punct ,
# smoky ADJ amod smoky
# , PUNCT punct ,
# smoky ADJ amod smoky
# yellow ADJ appos yellow
# . PUNCT punct .
# It PRON nsubj -PRON-
# becomes VERB ccomp become
# smoky ADJ advmod smoky
# yellow ADJ acomp yellow
# ; PUNCT punct ;
# it PRON nsubj -PRON-
# turns VERB ROOT turn
# smoky ADJ amod smoky
# yellow ADJ acomp yellow
# . PUNCT punct .
#
#
#  SPACE
#
#
# IZTAC ADJ compound iztac
# PAPALOTL ADJ ROOT papalotl
#
#  SPACE
#
# Some DET nsubj some
# are AUX ROOT be
# a DET det a
# little ADJ advmod little
# large ADJ amod large
# , PUNCT punct ,
# some DET det some
# average ADJ amod average
# , PUNCT punct ,
# some DET advmod some
# quite ADV advmod quite
# small ADJ acomp small
# . PUNCT punct .
# They PRON nsubj -PRON-
# are AUX ROOT be
# not PART neg not
# really ADV advmod really
# white ADJ acomp white
# , PUNCT punct ,
# only ADV advmod only
# as SCONJ prep as
# whitish ADJ pobj whitish
# , PUNCT punct ,
# only ADV advmod only
# as ADV advmod as
# pale ADJ advcl pale
# as SCONJ mark as
# they PRON nsubj -PRON-
# are AUX advcl be
# yellow ADJ acomp yellow
# . PUNCT punct .
#
#
#  SPACE
#
#
# CHIAN PROPN compound CHIAN
# PAPALOTL PROPN ROOT PAPALOTL
# . PUNCT punct .
#
#  SPACE
#
# It PRON nsubj -PRON-
# is AUX ROOT be
# somewhat ADV advmod somewhat
# similar ADJ acomp similar
# to ADP prep to
# the DET det the
# xicalpapalotl PROPN pobj xicalpapalotl
# , PUNCT punct ,
# because SCONJ mark because
# it PRON nsubjpass -PRON-
# is AUX auxpass be
# painted VERB advcl paint
# as SCONJ mark as
# if SCONJ mark if
# sprinkled VERB advcl sprinkle
# with ADP prep with
# chia PROPN pobj chia
# , PUNCT punct ,
# flecked VERB conj fleck
# everywhere ADV advmod everywhere
# on ADP prep on
# its PRON poss -PRON-
# body NOUN pobj body
# ; PUNCT punct ;
# and CCONJ cc and
# its PRON poss -PRON-
# wings NOUN nsubjpass wing
# are AUX auxpass be
# painted VERB conj paint
# , PUNCT punct ,
# painted VERB advcl paint
# with ADP prep with
# a DET det a
# chia NOUN compound chia
# design NOUN pobj design
# . PUNCT punct .
#
#
#  SPACE
#
#
# TEXOPAPALOTL PROPN ROOT TEXOPAPALOTL
#
#  SPACE
#
# Some DET nsubj some
# are AUX ccomp be
# large ADJ acomp large
# , PUNCT punct ,
# some DET nsubj some
# tiny ADJ acomp tiny
# ; PUNCT punct ;
# they PRON nsubj -PRON-
# are AUX ROOT be
# not PART neg not
# uniform ADJ acomp uniform
# . PUNCT punct .
# Its PRON poss -PRON-
# name NOUN nsubj name
# comes VERB ROOT come
# from ADP prep from
# texotli NOUN pobj texotli
# [ PUNCT punct [
# light PROPN amod light
# blue ADJ appos blue
# ] PUNCT punct ]
# . PUNCT punct .
# But CCONJ cc but
# it PRON nsubj -PRON-
# is AUX ccomp be
# not PART neg not
# really ADV advmod really
# a DET det a
# blue NOUN attr blue
# ; PUNCT punct ;
# it PRON nsubj -PRON-
# is AUX ROOT be
# just ADV advmod just
# so ADV advmod so
# rather ADV
# it PRON nsubj -PRON-
# becomes VERB ROOT become
# blue ADJ amod blue
# - PUNCT punct -
# brown ADJ acomp brown
# . PUNCT punct .
#
#
#  SPACE
#
#
# XOCHIPAPALOTL PROPN ROOT XOCHIPAPALOTL
#
#  SPACE
#
# Some DET nsubj some
# are AUX ROOT be
# large ADJ amod large
# , PUNCT punct ,
# some DET det some
# small ADJ acomp small
# . PUNCT punct .
# Many ADJ amod many
# kinds NOUN nsubj kind
# of ADP prep of
# colors NOUN pobj color
# are AUX ROOT be
# on ADP prep on
# them PRON pobj -PRON-
# , PUNCT punct ,
# that SCONJ mark that
# they PRON nsubjpass -PRON-
# are AUX auxpass be
# varicolored VERB advcl varicolore
# , PUNCT punct ,
# much ADV advmod much
# like SCONJ prep like
# flowers NOUN pobj flower
# , PUNCT punct ,
# of ADP prep of
# very ADV advmod very
# intricate ADJ amod intricate
# design NOUN pobj design
# , PUNCT punct ,
# and CCONJ cc and
# truly ADV advmod truly
# sought VERB conj seek
# after ADP prep after
# truly ADV advmod truly
# wonderful ADJ pobj wonderful
# . PUNCT punct .
# They PRON nsubj -PRON-
# are AUX ROOT be
# o INTJ nmod o
# intricate ADJ amod intricate
# design NOUN attr design
# , PUNCT punct ,
# sought VERB conj seek
# after ADP prep after
# , PUNCT punct ,
# flower NOUN compound flower
# - PUNCT punct -
# like ADJ intj like
# . PUNCT punct .
#
#
#  SPACE
#
#
# UAPPAPALOTL PROPN ROOT UAPPAPALOTL
#
#  SPACE
#
# It PRON nsubj -PRON-
# is AUX ccomp be

# %% [markdown]
# ### How many terms?

# %%
len(re.findall('papalotl', butterflies))

# %%
len(re.findall(r'butterfl\w+', butterflies))

# %% [markdown]
# ### Where are they?

# %%
from spacy.matcher import PhraseMatcher
from spacy import displacy

# %%
matcher = PhraseMatcher(nlp.vocab)
papalotl = nlp(butterflies)
phrase_list = ['butterfly', 'papalotl']
phrase_patterns = [nlp(text) for text in phrase_list]
matcher.add('mariposa', None, *phrase_patterns)
found_matches = matcher(papalotl)
print(found_matches)
# Out:
# [(4860986508236918519, 4, 5), (4860986508236918519, 132, 133), (4860986508236918519, 134, 135)]

# %%
for match_id, start, end in found_matches:
    string_id = nlp.vocab.strings[match_id]
    span = papalotl[start:end]
    print(start, end, span.text)
# Out:
# 4 5 butterfly
# 132 133 papalotl
# 134 135 butterfly

# %% [markdown]
# ### Dependencies

# %%
doc = nlp(sentences[0])

# %%
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="daddc7ce06b84dc0a7fda7b05180eaa7-0" class="displacy" width="3200" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Whatever</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">kind</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">butterfly,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">long</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">straight,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">abdomen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">slender,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">neck</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">constricted.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-daddc7ce06b84dc0a7fda7b05180eaa7-0-0" stroke-width="2px" d="M70,352.0 C70,2.0 1100.0,2.0 1100.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-daddc7ce06b84dc0a7fda7b05180eaa7-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-daddc7ce06b84dc0a7fda7b05180eaa7-0-1" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-daddc7ce06b84dc0a7fda7b05180eaa7-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-daddc7ce06b84dc0a7fda7b05180eaa7-0-2" stroke-width="2px" d="M70,352.0 C70,177.0 390.0,177.0 390.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-daddc7ce06b84dc0a7fda7b05180eaa7-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M390.0,354.0 L398.0,342.0 382.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-daddc7ce06b84dc0a7fda7b05180eaa7-0-3" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-daddc7ce06b84dc0a7fda7b05180eaa7-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M560.0,354.0 L568.0,342.0 552.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-daddc7ce06b84dc0a7fda7b05180eaa7-0-4" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-daddc7ce06b84dc0a7fda7b05180eaa7-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M735.0,354.0 L743.0,342.0 727.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-daddc7ce06b84dc0a7fda7b05180eaa7-0-5" stroke-width="2px" d="M945,352.0 C945,264.5 1085.0,264.5 1085.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-daddc7ce06b

# %% [markdown]
# ### Part-of-speech tagging

# %%
for i in range(len(sentences)):
    doc = nlp(sentences[i])
    pos = [(w.text, w.pos_) for w in doc]
    for j in pos:
        if j[1] == 'ADJ':
            print(j[0])
# Out:
# long
# straight
# slender
# fuzzy
# twofold
# constant
# different
# fuzzy
# solid
# many
# large
# yellow
# yellow
# fuzzy
# black
# beautiful
# coveted
# desirable
# desirable
# fragile
# firm
# similar
# same
# black
# little
# little
# smoky
# tawny
# smoky
# smoky
# yellow
# smoky
# yellow
# smoky
# yellow
# little
# large
# average
# small
# white
# whitish
# pale
# yellow
# similar
# large
# tiny
# uniform
# pale
# pallid
# yellow
# livid
# light
# blue
# light
# blue
# blue
# large
# small
# Many
# intricate
# wonderful
# intricate
# like
# average
# beautiful
# wonderful
# amaranth
# mature
# ripe
# yellow

# %%
for i in range(len(sentences)):
    doc = nlp(sentences[i])
    pos = [(w.text, w.pos_) for w in doc]
    for j in pos:
        if j[1] == 'VERB':
            print(j[0])
# Out:
# constricted
# winged
# trembles
# beats
# flies
# sucks
# sucks
# comes
# painted
# varicolored
# required
# yellows
# becomcs
# painted
# becomes
# varicolored
# breeds
# becomes
# develops
# flies
# flecked
# varicolored
# TLECOCOZPAPALOTL
# called
# fireyellow
# glows
# glistens
# glows
# glistens
# becomes
# turns
# PAPALOTL
# painted
# sprinkled
# flecked
# painted
# painted
# comes
# takes
# becomes
# varicolored
# sought
# sought
# painted
# called
# become
# named
# become
