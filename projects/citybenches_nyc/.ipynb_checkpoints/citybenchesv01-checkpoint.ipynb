# %%
G = ox.graph_from_address('N. Sicily Pl., Chandler, Arizona', distance=800, network_type='drive')
route = nx.shortest_path(G, origin, destination)
ox.plot_graph_route(G, route)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-405c49c6192f> in <module>
#       1 G = ox.graph_from_address('N. Sicily Pl., Chandler, Arizona', distance=800, network_type='drive')
# ----> 2 route = nx.shortest_path(G, origin, destination)
#       3 ox.plot_graph_route(G, route)
#
# NameError: name 'nx' is not defined

# %%
#Die folgenden Packages sind für die Codierung von Karten in Graphen nötig
import osmnx as ox 
import networkx as nx
import geopandas

#Dieses Package benötigen wir für das Plotten von Karten
import matplotlib

startpoint = ox.geocode('5030 Broadway, New York City, New York, USA')
G = ox.graph_from_point('Manhattan, New York City, New York, USA', network_type = 'walk', simplify = True)
bank1 = ox.geocode('5030 Broadway, New York City, New York, USA')
bank2 = ox.geocode('54 Nagle Avenue, New York City, New York, USA')
bank1n = ox.get_nearest_node(G, bank1)
bank2n = ox.get_nearest_node(G, bank2)
route = nx.shortest_path(G, bank1n, bank2n, weight = 'length')
print(route)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-c6553ab5c279> in <module>
#       5 import matplotlib
#       6 startpoint = ox.geocode('5030 Broadway, New York City, New York, USA')
# ----> 7 G = ox.graph_from_place('Manhattan, New York City, New York, USA', network_type = 'walk', simplify = True)
#       8 bank1 = ox.geocode('5030 Broadway, New York City, New York, USA')
#       9 bank2 = ox.geocode('54 Nagle Avenue, New York City, New York, USA')
#
# ~/anaconda3/lib/python3.7/site-packages/osmnx/core.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, name, which_result, buffer_dist, timeout, memory, max_query_area_size, clean_periphery, infrastructure, custom_filter, custom_settings)
#    1495                            max_query_area_size=max_query_area_size,
#    1496                            clean_periphery=clean_periphery, infrastructure=infrastructure,
# -> 1497                            custom_filter=custom_filter, custom_settings=custom_settings)
#    1498
#    1499     log('graph_from_place() returning graph with {:,} nodes and {:,} edges'.format(len(list(G.nodes())), len(list(G.edges()))))
#
# ~/anaconda3/lib/python3.7/site-packages/osmnx/core.py in graph_from_polygon(polygon, network_type, simplify, retain_all, truncate_by_edge, name, timeout, memory, max_query_area_size, clean_periphery, infrastructure, custom_filter, custom_settings)
#    1377         # segments in the network, but in reality also connect to an
#    1378         # intersection just outside the polygon
# -> 1379         G = truncate_graph_polygon(G_buffered, polygon, retain_all=retain_all, truncate_by_edge=truncate_by_edge)
#    1380
#    1381         # count how many street segments in buffered graph emanate from each
#
# ~/anaconda3/lib/python3.7/site-packages/osmnx/core.py in truncate_graph_polygon(G, polygon, retain_all, truncate_by_edge, quadrat_width, min_num, buffer_amount)
#     743
#     744     # find all the nodes in the graph that lie outside the polygon
# --> 745     points_within_geometry = intersect_index_quadrats(gdf_nodes, polygon, quadrat_width=quadrat_width, min_num=min_num, buffer_amount=buffer_amount)
#     746     nodes_outside_polygon = gdf_nodes[~gdf_nodes.index.isin(points_within_geometry.index)]
#     747
#
# ~/anaconda3/lib/python3.7/site-packages/osmnx/core.py in intersect_index_quadrats(gdf, geometry, quadrat_width, min_num, buffer_amount)
#     684             possible_matches_index = list(sindex.intersection(poly.bounds))
#     685             possible_matches = gdf.iloc[possible_matches_index]
# --> 686             precise_matches = possible_matches[possible_matches.intersects(poly)]
#     687             points_within_geometry = points_within_geometry.append(precise_matches)
#     688
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/base.py in intersects(self, other)
#     388             intersected.
#     389         """
# --> 390         return _binary_op("intersects", self, other)
#     391
#     392     def overlaps(self, other):
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/base.py in _binary_op(op, this, other, *args, **kwargs)
#      70     # type: (str, GeoSeries, GeoSeries, args/kwargs) -> Series[bool/float]
#      71     """Binary operation on GeoSeries objects that returns a Series"""
# ---> 72     data, index = _delegate_binary_method(op, this, other, *args, **kwargs)
#      73     return Series(data, index=index)
#      74
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/base.py in _delegate_binary_method(op, this, other, *args, **kwargs)
#      54         raise TypeError(type(this), type(other))
#      55
# ---> 56     data = getattr(a_this, op)(other, *args, **kwargs)
#      57     return data, this.index
#      58
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/array.py in intersects(self, other)
#     609
#     610     def intersects(self, other):
# --> 611         return _binary_predicate("intersects", self, other)
#     612
#     613     def overlaps(self, other):
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/array.py in _binary_predicate(op, left, right, *args, **kwargs)
#     289         data = [
#     290             getattr(s, op)(right, *args, **kwargs) if s is not None else False
# --> 291             for s in left.data
#     292         ]
#     293         return np.array(data, dtype=bool)
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/array.py in <listcomp>(.0)
#     289         data = [
#     290             getattr(s, op)(right, *args, **kwargs) if s is not None else False
# --> 291             for s in left.data
#     292         ]
#     293         return np.array(data, dtype=bool)
#
# ~/anaconda3/lib/python3.7/site-packages/shapely/geometry/base.py in intersects(self, other)
#     738     def intersects(self, other):
#     739         """Returns True if geometries intersect, else False"""
# --> 740         return bool(self.impl['intersects'](self, other))
#     741
#     742     def overlaps(self, other):
#
# ~/anaconda3/lib/python3.7/site-packages/shapely/predicates.py in __call__(self, this, other, *args)
#      13         self._validate(other, stop_prepared=True)
#      14         try:
# ---> 15             return self.fn(this._geom, other._geom, *args)
#      16         except PredicateError as err:
#      17             # Dig deeper into causes of errors.
#
# ~/anaconda3/lib/python3.7/site-packages/shapely/geos.py in errcheck_predicate(result, func, argtuple)
#     575
#     576
# --> 577 def errcheck_predicate(result, func, argtuple):
#     578     """Result is 2 on exception, 1 on True, 0 on False"""
#     579     if result == 2:
#
# KeyboardInterrupt:

# %%
#Nötige Packages
import osmnx as ox
import networkx as nx
import geopandas 
import matplotlib.pyplot as plt

#Im Radius von 400m um diesen Punkt wird ein Ausschnitt der Karte von New York betrachtet 
startpoint = ox.geocode('2394 Adam Clayton Powell Jr Blvd, New York City')

#Die Lokalisation der Bänke in Koordinaten
bank1 = ox.geocode('120 W 140th Street, New York City')
bank2 = ox.geocode('2394 Adam Clayton Powell Jr Blvd, New York City')

#Die Lokalisation der Bänke in Nodes
bank1n = ox.get_nearest_node(G,bank1)
bank2n = ox.get_nearest_node(G,bank2)

#Die Distanz der jeweils nächsten Nodes zueinander wird nun geplottet und in Metern berechnet
G = ox.graph_from_point(startpoint, network_type = 'walk', distance = 400, simplify = False)
route = nx.shortest_path(G, bank1n, bank2n, weight = 'length')
ox.plot_graph_route(G, route)
routem = nx.shortest_path_length(G, bank1n, bank2n, weight = 'length')
print(routem)
# Out:
# (40.8184016, -73.9417655)
# [5378686567, 2141026520, 42433781, 5378420478]
