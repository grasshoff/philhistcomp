# %% [markdown]
# # Project Disagreement

# %% [markdown]
# ### Step 1: Search for documents in the [DIMENSIONS](https://app.dimensions.ai/discover/publication) database and create an Excel-file containing search results ("search_results.xlsx").
# * Run a query in the search bar.
#
# (I chose search option "DOI" and searched for known DOIs. One of my documents has no DOI, so I chose search option "Title and abstract" and searched for some sentences of this document's "SUMMARY" section.)
#
# * Klick on "Save/Export" (on the right next to the search bar) and export the list of search results. Choose to export the results as an Excel-file.
#
# (In this way I created "hcq.xlsx".)

# %% [markdown]
# ### Step 2: Make a Dataframe out of the Excel-file

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import json

# %%
df_hcq = pd.read_excel("hcq.xlsx",skiprows=[0])

# %%
df_hcq
# Out:
#     Rank  Publication ID                                DOI        PMID  \
# 0    113  pub.1126880632         10.1186/s12969-020-00422-z  32321540.0
# 1     65  pub.1127125006         10.1186/s13054-020-02894-7  32345336.0
# 2     58  pub.1125978056       10.1016/j.medmal.2020.03.006  32240719.0
# 3    109  pub.1127834352      10.1016/s0140-6736(20)31180-6  32450107.0
# 4     20  pub.1126667578        10.1101/2020.04.10.20060558         NaN
# 5      0  pub.1125404383    10.1016/j.antiviral.2020.104762  32147496.0
# 6     63  pub.1127182972             10.4414/smw.2020.20262  32347963.0
# 7     19  pub.1126839717        10.1101/2020.04.14.20065276         NaN
# 8     21  pub.1126655433        10.1101/2020.04.10.20060699         NaN
# 9      0  pub.1126626949        10.1101/2020.04.07.20056424         NaN
# 10   104  pub.1126596624         10.1007/s10067-020-05073-9  32277367.0
# 11    65  pub.1126391895                  10.1136/bmj.m1432  32269046.0
# 12   105  pub.1127408847       10.26355/eurrev_202004_21038  32373993.0
# 13    61  pub.1125821294          10.1038/s41565-020-0674-9  32203437.0
# 14    21  pub.1126021329        10.1101/2020.03.22.20040758         NaN
# 15   108  pub.1125793694  10.1016/j.ijantimicag.2020.105949  32205204.0
# 16   105  pub.1124953197             10.5582/bst.2020.01047  32074550.0
# 17   108  pub.1127161884      10.1080/22221751.2020.1760145  32338155.0
# 18   865  pub.1127181539                                NaN  32335561.0
#
#          PMCID                                              Title  \
# 0   PMC7175817  COVID-19 and what pediatric rheumatologists sh...
# 1   PMC7187670  Shining a light on the evidence for hydroxychl...
# 2   PMC7195369  No Evidence of Rapid Antiviral Clearance or Cl...
# 3   PMC7255293  Hydroxychloroquine or chloroquine with or with...
# 4          NaN  Hydroxychloroquine in patients mainly with mil...
# 5   PMC7132364                        Of chloroquine and COVID-19
# 6          NaN  An independent appraisal and re-analysis of hy...
# 7          NaN  Hydroxychloroquine Versus COVID-19: A Periodic...
# 8          NaN  No evidence of clinical efficacy of hydroxychl...
# 9          NaN  Chloroquine diphosphate in two different dosag...
# 10  PMC7145936  Rheumatologists’ perspective on coronavirus di...
# 11         NaN     Chloroquine and hydroxychloroquine in covid-19
# 12         NaN  Efficacy of chloroquine and hydroxychloroquine...
# 13  PMC7094976  Insights from nanomedicine into chloroquine ef...
# 14         NaN  Efficacy of hydroxychloroquine in patients wit...
# 15  PMC7102549  Hydroxychloroquine and azithromycin as a treat...
# 16         NaN  Breakthrough: Chloroquine phosphate has shown ...
# 17         NaN  Rheumotologitsts’ view on the use of hydroxych...
# 18         NaN  Update on treatment of COVID-19: ongoing studi...
#
#                                          Source title  Anthology title  \
# 0                              Pediatric Rheumatology              NaN
# 1                                       Critical Care              NaN
# 2                   Médecine et Maladies Infectieuses              NaN
# 3                                          The Lancet              NaN
# 4                                             medRxiv              NaN
# 5                                  Antiviral Research              NaN
# 6                                Swiss Medical Weekly              NaN
# 7                                             medRxiv              NaN
# 8                                             medRxiv              NaN
# 9                                             medRxiv              NaN
# 10                              Clinical Rheumatology              NaN
# 11                                            The BMJ              NaN
# 12  European review for medical and pharmacologica...              NaN
# 13                              Nature Nanotechnology              NaN
# 14                                            medRxiv              NaN
# 15      International Journal of Antimicrobial Agents              NaN
# 16                                  BioScience Trends              NaN
# 17                     Emerging Microbes & Infections              NaN
# 18                           Le infezioni in medicina              NaN
#
#                                            MeSH terms Publication Date  ...  \
# 0   Adolescent; Anti-Inflammatory Agents, Non-Ster...          2020-12  ...
# 1   Betacoronavirus; Coronavirus Infections; Human...          2020-12  ...
# 2   Adult; Aged; Antiviral Agents; Azithromycin; B...          2020-06  ...
# 3                                                 NaN          2020-05  ...
# 4                                                 NaN          2020-05  ...
# 5   Antiviral Agents; Betacoronavirus; China; Chlo...          2020-05  ...
# 6   Adult; Azithromycin; Betacoronavirus; Clinical...       2020-04-29  ...
# 7                                                 NaN       2020-04-20  ...
# 8                                                 NaN       2020-04-14  ...
# 9                                                 NaN       2020-04-11  ...
# 10                                                NaN       2020-04-10  ...
# 11  Antiviral Agents; Betacoronavirus; Chloroquine...       2020-04-08  ...
# 12  Antiviral Agents; Betacoronavirus; Chloroquine...          2020-04  ...
# 13  Antiviral Agents; Betacoronavirus; Chloroquine...          2020-04  ...
# 14                                                NaN       2020-03-30  ...
# 15                                                NaN          2020-03  ...
# 16  Betacoronavirus; China; Chloroquine; Clinical ...       2020-02-29  ...
# 17  Antimalarials; Antirheumatic Agents; Antiviral...       2020-01-01  ...
# 18  Betacoronavirus; Chloroquine; Clinical Trials ...             2020  ...
#
#                                  Corresponding Author  \
# 0   Giani, Teresa (Meyer Children's Hospital; Univ...
# 1     Ingraham, Nicholas E. (University of Minnesota)
# 2           Molina, Jean Michel (Hôpital Saint-Louis)
# 3     Mehra, Mandeep R (Brigham and Women's Hospital)
# 4                                                 NaN
# 5   de Lamballerie, Xavier (Méditerranée Infection...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Misra, Durga Prasanna (Sanjay Gandhi Post Grad...
# 11         Ferner, Robin E (University of Birmingham)
# 12                                                NaN
# 13                    Hu, Tony Y. (Tulane University)
# 14                                                NaN
# 15  Raoult, Didier (Méditerranée Infection Foundat...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
#
#                                  Authors Affiliations  Times cited  \
# 0   Licciardi, Francesco (University of Turin); Gi...            1
# 1   Ingraham, Nicholas E. (University of Minnesota...            0
# 2   Molina, Jean Michel (Hôpital Saint-Louis); Del...           67
# 3   Mehra, Mandeep R (Brigham and Women's Hospital...            7
# 4   Tang, Wei (Shanghai Jiao Tong University); Cao...           33
# 5   Touret, Franck (Méditerranée Infection Foundat...           67
# 6   Intson, Katheron (University of Toronto); Kuma...            0
# 7   Shamshirian, Amir (Mazandaran University of Me...            4
# 8   Mahevas, Matthieu (); Tran, Viet-Thi (); Roumi...           27
# 9   Borba, Mayla Gabriela Silva (University of the...           21
# 10  Misra, Durga Prasanna (Sanjay Gandhi Post Grad...            8
# 11  Ferner, Robin E (University of Birmingham); Ar...           20
# 12  Meo, S A (King Saud University); Klonoff, D C ...            0
# 13  Hu, Tony Y. (Tulane University); Frieman, Matt...           20
# 14  Chen, Zhaowei (Renmin Hospital of Wuhan Univer...           82
# 15  Gautret, Philippe (Méditerranée Infection Foun...          492
# 16  Gao, Jianjun (Qingdao University); Tian, Zhenx...          346
# 17  Sun, Xiaoxuan (Jiangsu Province Hospital); Ni,...            0
# 18  Esposito, Silvano (University of Salerno); Nov...            1
#
#    Recent citations RCR FCR  \
# 0                 1 NaN NaN
# 1                 0 NaN NaN
# 2                67 NaN NaN
# 3                 7 NaN NaN
# 4                33 NaN NaN
# 5                67 NaN NaN
# 6                 0 NaN NaN
# 7                 4 NaN NaN
# 8                27 NaN NaN
# 9                21 NaN NaN
# 10                8 NaN NaN
# 11               20 NaN NaN
# 12                0 NaN NaN
# 13               20 NaN NaN
# 14               82 NaN NaN
# 15              492 NaN NaN
# 16              346 NaN NaN
# 17                0 NaN NaN
# 18                1 NaN NaN
#
#                                        Source Linkout  \
# 0   https://ped-rheum.biomedcentral.com/track/pdf/...
# 1   https://ccforum.biomedcentral.com/track/pdf/10...
# 2        https://doi.org/10.1016/j.medmal.2020.03.006
# 3       https://doi.org/10.1016/s0140-6736(20)31180-6
# 4   https://www.medrxiv.org/content/medrxiv/early/...
# 5     https://doi.org/10.1016/j.antiviral.2020.104762
# 6   https://smw.ch/journalfile/view/article/ezm_sm...
# 7   https://www.medrxiv.org/content/medrxiv/early/...
# 8   https://www.medrxiv.org/content/medrxiv/early/...
# 9   https://www.medrxiv.org/content/medrxiv/early/...
# 10  https://link.springer.com/content/pdf/10.1007/...
# 11  https://www.bmj.com/content/bmj/369/bmj.m1432....
# 12                                                NaN
# 13  https://www.nature.com/articles/s41565-020-067...
# 14  https://www.medrxiv.org/content/medrxiv/early/...
# 15  https://doi.org/10.1016/j.ijantimicag.2020.105949
# 16  https://www.jstage.jst.go.jp/article/bst/14/1/...
# 17  https://www.tandfonline.com/doi/pdf/10.1080/22...
# 18                                                NaN
#
#                                        Dimensions URL  \
# 0   https://app.dimensions.ai/details/publication/...
# 1   https://app.dimensions.ai/details/publication/...
# 2   https://app.dimensions.ai/details/publication/...
# 3   https://app.dimensions.ai/details/publication/...
# 4   https://app.dimensions.ai/details/publication/...
# 5   https://app.dimensions.ai/details/publication/...
# 6   https://app.dimensions.ai/details/publication/...
# 7   https://app.dimensions.ai/details/publication/...
# 8   https://app.dimensions.ai/details/publication/...
# 9   https://app.dimensions.ai/details/publication/...
# 10  https://app.dimensions.ai/details/publication/...
# 11  https://app.dimensions.ai/details/publication/...
# 12  https://app.dimensions.ai/details/publication/...
# 13  https://app.dimensions.ai/details/publication/...
# 14  https://app.dimensions.ai/details/publication/...
# 15  https://app.dimensions.ai/details/publication/...
# 16  https://app.dimensions.ai/details/publication/...
# 17  https://app.dimensions.ai/details/publication/...
# 18  https://app.dimensions.ai/details/publication/...
#
#                               FOR (ANZSRC) Categories  \
# 0   1108 Medical Microbiology; 11 Medical and Heal...
# 1                      11 Medical and Health Sciences
# 2                                                 NaN
# 3   1117 Public Health and Health Services; 11 Med...
# 4   1117 Public Health and Health Services; 11 Med...
# 5   1108 Medical Microbiology; 11 Medical and Heal...
# 6   11 Medical and Health Sciences; 1103 Clinical ...
# 7   1117 Public Health and Health Services; 11 Med...
# 8   1117 Public Health and Health Services; 11 Med...
# 9   11 Medical and Health Sciences; 1103 Clinical ...
# 10  11 Medical and Health Sciences; 1103 Clinical ...
# 11  1117 Public Health and Health Services; 11 Med...
# 12  1108 Medical Microbiology; 11 Medical and Heal...
# 13                                                NaN
# 14  11 Medical and Health Sciences; 1103 Clinical ...
# 15  1108 Medical Microbiology; 11 Medical and Heal...
# 16  1108 Medical Microbiology; 11 Medical and Heal...
# 17          0605 Microbiology; 06 Biological Sciences
# 18  11 Medical and Health Sciences; 1103 Clinical ...
#
#     Sustainable Development Goals
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3    3 Good Health and Well Being
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7    3 Good Health and Well Being
# 8                             NaN
# 9                             NaN
# 10                            NaN
# 11   3 Good Health and Well Being
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16   3 Good Health and Well Being
# 17                            NaN
# 18                            NaN
#
# [19 rows x 27 columns]

# %% [markdown]
# ## Exploit Websites

# %%
pubkeys = [
    'title',
    'aff_org_name',
    'researcher_dim_id',
    'researcher_dim_count',
    'journal_title',
    'language',
    'abstract',
    'open_access',
    'publisher',
    'aff_city_name',
    'aff_country_name',
    'doi',
    'pub_date',
    'pub_year',
    'times_cited',
    'altmetric_id',
    'altmetric',
    'authors_full'
    ]

# %%
def getmeta(x):
    html = ""
    d = ""
    value = ""
    url = x["Dimensions URL"]
    
    if url != None:
        html = requests.get(url).content
        
    soup = BeautifulSoup(html, "lxml")
    datadoc = soup.find("div")
    
    if datadoc == None:
        attr = ""
    else:
        attr = datadoc.get("data-doc")
        if attr:
            d = json.loads(attr)
    
    dicpub = dict()
    
    for i in pubkeys:
        if d != "":
            value = d.get(i, "NaN")
        dicpub[i] = value
        
    return(dicpub)

# %%
df_hcq["seldict"] = df_hcq.apply(getmeta, axis=1)

# %%
lidi = []
def newpub(x):
    di = dict()
    d = x["seldict"]
    di["DOI"] = x["DOI"]
    di["title"] = x["Title"]
    di["authors"] = d["authors_full"]
    di["publisher"] = d["publisher"]
    di["source"] = x["Source title"]
    di["aff_org_name"] = d["aff_org_name"]
    di["aff_country"] = d["aff_country_name"]
    di["pub_date"] = d["pub_date"]
    di["abstract"] = d["abstract"]
    di["openaccess"] = d["open_access"]
    di["di_URL"] = x["Dimensions URL"]
    lidi.append(di)

# %%
df_hcq.apply(lambda x:newpub(x), axis=1)
df_hcq_Lit = pd.DataFrame(lidi)
df_hcq_Lit.head()
# Out:
#                              DOI  \
# 0     10.1186/s12969-020-00422-z
# 1     10.1186/s13054-020-02894-7
# 2   10.1016/j.medmal.2020.03.006
# 3  10.1016/s0140-6736(20)31180-6
# 4    10.1101/2020.04.10.20060558
#
#                                                title  \
# 0  COVID-19 and what pediatric rheumatologists sh...
# 1  Shining a light on the evidence for hydroxychl...
# 2  No Evidence of Rapid Antiviral Clearance or Cl...
# 3  Hydroxychloroquine or chloroquine with or with...
# 4  Hydroxychloroquine in patients mainly with mil...
#
#                                              authors        publisher  \
# 0  [Francesco Licciardi, Teresa Giani, Letizia Ba...  Springer Nature
# 1  [Nicholas E. Ingraham, David Boulware, Matthew...  Springer Nature
# 2  [Jean Michel Molina, Constance Delaugerre, Jer...         Elsevier
# 3  [Mandeep R Mehra, Sapan S Desai, Frank Ruschit...         Elsevier
# 4  [Wei Tang, Zhujun Cao, Mingfeng Han, Zhengyan ...              NaN
#
#                               source  \
# 0             Pediatric Rheumatology
# 1                      Critical Care
# 2  Médecine et Maladies Infectieuses
# 3                         The Lancet
# 4                            medRxiv
#
#                                         aff_org_name  \
# 0  [University of Siena, University of Turin, Div...
# 1  [University of North Carolina at Chapel Hill, ...
# 2  [University of Paris-Sud, Hôpital Saint-Louis,...
# 3  [Brigham and Women's Hospital, University Hosp...
# 4  [Department of Respiratory Medicine. No.2 peop...
#
#                     aff_country pub_date  \
# 0                       [Italy]  2020-12
# 1               [United States]  2020-12
# 2                      [France]  2020-06
# 3  [Switzerland, United States]  2020-05
# 4                       [China]  2020-05
#
#                                             abstract  openaccess  \
# 0  On March 11th, 2020 the World Health Organizat...        True
# 1                                                           True
# 2                                                           True
# 3  BACKGROUND: Hydroxychloroquine or chloroquine,...        True
# 4  Abstract Objectives To assess the efficacy and...        True
#
#                                               di_URL
# 0  https://app.dimensions.ai/details/publication/...
# 1  https://app.dimensions.ai/details/publication/...
# 2  https://app.dimensions.ai/details/publication/...
# 3  https://app.dimensions.ai/details/publication/...
# 4  https://app.dimensions.ai/details/publication/...

# %%
hcq_abstracts = df_hcq_Lit["abstract"]
hcq_abstracts
# Out:
# 0     On March 11th, 2020 the World Health Organizat...
# 1
# 2
# 3     BACKGROUND: Hydroxychloroquine or chloroquine,...
# 4     Abstract Objectives To assess the efficacy and...
# 5     Recent publications have brought attention to ...
# 6     A recent open-label study claimed that hydroxy...
# 7     Abstract Importance: This systematic review an...
# 8     Background Treatments are urgently needed to p...
# 9      Background There is no specific antiviral the...
# 10    The ongoing pandemic coronavirus disease 19 (C...
# 11    Use of these drugs is premature and potentiall...
# 12    OBJECTIVE: The novel severe acute respiratory ...
# 13    Chloroquine — an approved malaria drug — is kn...
# 14    Aims: Studies have indicated that chloroquine ...
# 15    BACKGROUND: Chloroquine and hydroxychloroquine...
# 16    The coronavirus disease 2019 (COVID-19) virus ...
# 17    The current pandemic coronavirus disease 2019 ...
# 18    The COVID-19 pandemic represents the greatest ...
# Name: abstract, dtype: object
