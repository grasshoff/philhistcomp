# %% [markdown]
# ### Preparing and Analysing a Sample Text: Elizabeth S. Haldane's (1911) English translation of Descartes' *Meditationes*

# %% [markdown]
# **3. Analysis (cont.)**

# %%
import pandas as pd
import re

# %%
import spacy

# %%
Meditationes_soul = open('Meditationes_soul.txt', encoding="utf8")

# %%
sample_Soul = Meditationes_soul.read()

# %%
from spacy.lang.en import English

raw_text = sample_Soul
nlp = English()
nlp.add_pipe(nlp.create_pipe('sentencizer'))
doc_soul = nlp(raw_text)
sentences = [sent.string.strip() for sent in doc_soul.sents]

# %%
sentences
# Out:
# ['In addition to this I considered that I was nourished, that I walked, that I\nfelt, and that I thought, and I referred all these actions to\nthe soul:  but I did not stop to consider what the soul was,\nor if I did stop, I imagined that it was something extremely\nrare and subtle like a wind, a flame, or an ether, which was\nspread throughout my grosser parts.',
#  'Let us pass to the attributes of soul and see if there is any one which is in me?',
#  'I do not now admit anything which is not necessarily true:  to\nspeak accurately I am not more than a thing which thinks, that\nis to say a mind or a soul, or an understanding, or a reason,\nwhich are terms whose significance was formerly unknown to me.',
#  'And although possibly (or rather certainly, as I shall say in a\nmoment) I possess a body with which I am very intimately\nconjoined, yet because, on the one side, I have a clear and\ndistinct idea of myself inasmuch as I am only a thinking and\nunextended thing, and as, on the other, I possess a distinct\nidea of body, inasmuch as it is only an extended and\nunthinking thing, it is certain that this I [that is to say,\nmy soul by which I am what I am], is entirely and absolutely\ndistinct from my body, and can exist without it.',
#  'And also from the fact that amongst these different sense-perceptions some\nare very agreeable to me and others disagreeable, it is quite\ncertain that my body (or rather myself in my entirety,\ninasmuch as I am formed of body and soul) may receive\ndifferent impressions agreeable and disagreeable from the\nother bodies which surround it.',
#  'But certainly although in regard to the dropsical body it\nis only so to speak to apply an extrinsic term when we say\nthat its nature is corrupted, inasmuch as apart from the need\nto drink, the throat is parched; yet in regard to the\ncomposite whole, that is to say, to the mind or soul united to\nthis body, it is not a purely verbal predicate, but a real\nerror of nature, for it to have thirst when drinking would be\nhurtful to it.',
#  'But it is quite otherwise with corporeal or extended objects, for there is not one of these\nimaginable by me which my mind cannot easily divide into\nparts, and which consequently I do not recognise as being\ndivisible; this would be sufficient to teach me that the mind\nor soul of man is entirely different from the body, if I had\nnot already learned it from other sources.',
#  '']

# %%
sentences = [item.replace('\n', " ") for item in sentences]
print (sentences)
# Out:
# ['In addition to this I considered that I was nourished, that I walked, that I felt, and that I thought, and I referred all these actions to the soul:  but I did not stop to consider what the soul was, or if I did stop, I imagined that it was something extremely rare and subtle like a wind, a flame, or an ether, which was spread throughout my grosser parts.', 'Let us pass to the attributes of soul and see if there is any one which is in me?', 'I do not now admit anything which is not necessarily true:  to speak accurately I am not more than a thing which thinks, that is to say a mind or a soul, or an understanding, or a reason, which are terms whose significance was formerly unknown to me.', 'And although possibly (or rather certainly, as I shall say in a moment) I possess a body with which I am very intimately conjoined, yet because, on the one side, I have a clear and distinct idea of myself inasmuch as I am only a thinking and unextended thing, and as, on the other, I possess a distinct idea of body, inasmuch as it is only an extended and unthinking thing, it is certain that this I [that is to say, my soul by which I am what I am], is entirely and absolutely distinct from my body, and can exist without it.', 'And also from the fact that amongst these different sense-perceptions some are very agreeable to me and others disagreeable, it is quite certain that my body (or rather myself in my entirety, inasmuch as I am formed of body and soul) may receive different impressions agreeable and disagreeable from the other bodies which surround it.', 'But certainly although in regard to the dropsical body it is only so to speak to apply an extrinsic term when we say that its nature is corrupted, inasmuch as apart from the need to drink, the throat is parched; yet in regard to the composite whole, that is to say, to the mind or soul united to this body, it is not a purely verbal predicate, but a real error of nature, for it to have thirst when drinking would be hurtful to it.', 'But it is quite otherwise with corporeal or extended objects, for there is not one of these imaginable by me which my mind cannot easily divide into parts, and which consequently I do not recognise as being divisible; this would be sufficient to teach me that the mind or soul of man is entirely different from the body, if I had not already learned it from other sources.', '']

# %%
df = pd.DataFrame(sentences) 
df.columns = ['statements on soul']
df[:7]
# Out:
#                                   statements on soul
# 0  In addition to this I considered that I was no...
# 1  Let us pass to the attributes of soul and see ...
# 2  I do not now admit anything which is not neces...
# 3  And although possibly (or rather certainly, as...
# 4  And also from the fact that amongst these diff...
# 5  But certainly although in regard to the dropsi...
# 6  But it is quite otherwise with corporeal or ex...

# %% [markdown]
# #### (Partial) manual analysis of statements on soul, indicating challenges for nlp:
#
# 1. Descartes seems to *start* discussing the attributes of the soul. He might subsequently make use of pronoun 'it' to refer to soul. This problem can be solved by extending scope of spacy matcher (as discussed in "ideal_strategy").
# 2. soul =  mind = understanding = reason. Not sure if spacy can detect this characterisation of soul "by substitution".
# 3. relation soul/body: soul distinct from body, its existence does not depend on existence of body. Resembles Suárez' conception of relation soul/body, but some important differences. Not sure if spacy can detect those differences (or rather: not (yet) sure *how* spacy could detect them).
#
# **conclusion/insight:** method still requires refinement, analysing semantic similarity between adjectives and verbs used in connection with term 'soul' (e.g. in Descartes' and Suárez' writings) would entirely miss the point

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc_soul = nlp(sample_Soul)

# %%
for token in doc_soul:
    print(token, token.pos_, token.dep_, token.head)
# Out:
# In ADP prep considered
# addition NOUN pobj In
# to ADP prep addition
# this DET pobj to
# I PRON nsubj considered
# considered VERB ROOT considered
# that SCONJ mark nourished
# I PRON nsubjpass nourished
# was AUX auxpass nourished
# nourished VERB ccomp considered
# , PUNCT punct considered
# that SCONJ mark walked
# I PRON nsubj walked
# walked VERB ccomp considered
# , PUNCT punct felt
# that SCONJ mark felt
# I PRON nsubj felt
#
#  SPACE  I
# felt VERB ccomp considered
# , PUNCT punct felt
# and CCONJ cc felt
# that SCONJ mark thought
# I PRON nsubj thought
# thought VERB conj felt
# , PUNCT punct felt
# and CCONJ cc considered
# I PRON nsubj referred
# referred VERB conj considered
# all DET predet actions
# these DET det actions
# actions NOUN dobj referred
# to ADP prep referred
#
#  SPACE  to
# the DET det soul
# soul NOUN pobj to
# : PUNCT punct referred
#   SPACE  :
# but CCONJ cc stop
# I PRON nsubj stop
# did AUX aux stop
# not PART neg stop
# stop VERB ROOT stop
# to PART aux consider
# consider VERB xcomp stop
# what PRON attr was
# the DET det soul
# soul NOUN nsubj was
# was AUX ccomp consider
# , PUNCT punct stop
#
#  SPACE  ,
# or CCONJ cc imagined
# if SCONJ mark stop
# I PRON nsubj stop
# did AUX aux stop
# stop VERB advcl imagined
# , PUNCT punct imagined
# I PRON nsubj imagined
# imagined VERB ROOT imagined
# that SCONJ mark was
# it PRON nsubj was
# was AUX ccomp imagined
# something PRON attr was
# extremely ADV advmod rare
#
#  SPACE  extremely
# rare ADJ acomp was
# and CCONJ cc rare
# subtle ADJ conj rare
# like SCONJ prep subtle
# a DET det wind
# wind NOUN pobj like
# , PUNCT punct wind
# a DET det flame
# flame NOUN conj wind
# , PUNCT punct flame
# or CCONJ cc flame
# an DET det ether
# ether NOUN conj flame
# , PUNCT punct wind
# which DET nsubj was
# was AUX auxpass spread
#
#  SPACE  was
# spread VERB ROOT spread
# throughout ADP prep spread
# my DET poss parts
# grosser ADJ amod parts
# parts NOUN pobj throughout
# . PUNCT punct spread
#
#
#  SPACE  .
# Let VERB ROOT Let
# us PRON nsubj pass
# pass VERB ccomp Let
# to ADP prep pass
# the DET det attributes
# attributes NOUN pobj to
# of ADP prep attributes
# soul NOUN pobj of
# and CCONJ cc pass
# see VERB conj pass
# if SCONJ mark is
# there PRON expl is
# is AUX ccomp see
# any DET det one
# one NOUN attr is
# which DET nsubj is
# is AUX relcl one
# in ADP prep is
# me PRON pobj in
# ? PUNCT punct Let
#
#
#  SPACE  ?
# I PRON nsubj admit
# do AUX aux admit
# not PART neg admit
# now ADV advmod admit
# admit VERB ROOT admit
# anything PRON dobj admit
# which DET nsubj is
# is AUX relcl anything
# not PART neg is
# necessarily ADV advmod is
# true ADJ acomp is
# : PUNCT punct admit
#   SPACE  :
# to PART aux speak
#
#  SPACE  to
# speak VERB xcomp admit
# accurately ADV advmod speak
# I PRON nsubj am
# am AUX ROOT am
# not PART neg am
# more ADJ acomp am
# than SCONJ prep more
# a DET det thing
# thing NOUN pobj than
# which DET nsubj thinks
# thinks VERB relcl thing
# , PUNCT punct thinks
# that SCONJ nsubj is
#
#  SPACE  that
# is AUX ccomp thinks
# to PART aux say
# say VERB xcomp is
# a DET det mind
# mind NOUN dobj say
# or CCONJ cc mind
# a DET det soul
# soul NOUN conj mind
# , PUNCT punct soul
# or CCONJ cc soul
# an DET det understanding
# understanding NOUN conj soul
# , PUNCT punct understanding
# or CCONJ cc understanding
# a DET det reason
# reason NOUN conj understanding
# , PUNCT punct reason
#
#  SPACE  ,
# which DET nsubj are
# are AUX relcl mind
# terms NOUN attr are
# whose DET poss significance
# significance NOUN nsubj was
# was AUX relcl terms
# formerly ADV advmod was
# unknown ADJ acomp was
# to ADP prep unknown
# me PRON pobj to
# . PUNCT punct am
#
#
#  SPACE  .
# And CCONJ cc although
# although SCONJ ROOT although
# possibly ADV pcomp although
# ( PUNCT punct although
# or CCONJ cc although
# rather ADV advmod certainly
# certainly ADV advmod or
# , PUNCT punct although
# as SCONJ mark say
# I PRON nsubj say
# shall VERB aux say
# say VERB intj ,
# in ADP prep say
# a DET det moment
#
#  SPACE  a
# moment NOUN pobj in
# ) PUNCT punct say
# I PRON nsubj possess
# possess VERB ROOT possess
# a DET det body
# body NOUN dobj possess
# with ADP prep am
# which DET pobj with
# I PRON nsubj am
# am AUX relcl body
# very ADV advmod intimately
# intimately ADV advmod conjoined
#
#  SPACE  intimately
# conjoined VERB acomp am
# , PUNCT punct possess
# yet CCONJ cc possess
# because SCONJ mark have
# , PUNCT punct have
# on ADP prep have
# the DET det side
# one NUM nummod side
# side NOUN pobj on
# , PUNCT punct have
# I PRON nsubj have
# have AUX advcl possess
# a DET det idea
# clear ADJ amod idea
# and CCONJ cc clear
#
#  SPACE  and
# distinct ADJ amod idea
# idea NOUN dobj have
# of ADP prep idea
# myself PRON pobj of
# inasmuch ADJ acl idea
# as SCONJ mark am
# I PRON nsubj am
# am AUX advcl have
# only ADV advmod thinking
# a DET det thinking
# thinking NOUN attr am
# and CCONJ cc thinking
#
#  SPACE  and
# unextended VERB amod thing
# thing NOUN conj thinking
# , PUNCT punct have
# and CCONJ cc have
# as SCONJ mark possess
# , PUNCT punct possess
# on ADP prep possess
# the DET det other
# other ADJ pobj on
# , PUNCT punct possess
# I PRON nsubj possess
# possess VERB conj have
# a DET det idea
# distinct ADJ amod idea
#
#  SPACE  distinct
# idea NOUN dobj possess
# of ADP prep idea
# body NOUN pobj of
# , PUNCT punct possess
# inasmuch ADJ intj possess
# as SCONJ mark is
# it PRON nsubj is
# is AUX advcl is
# only ADV advmod thing
# an DET det thing
# extended ADJ amod thing
# and CCONJ cc extended
#
#  SPACE  and
# unthinking NOUN conj extended
# thing NOUN attr is
# , PUNCT punct is
# it PRON nsubj is
# is AUX ccomp possess
# certain ADJ acomp is
# that SCONJ mark is
# this DET det I
# I PRON nsubj is
# [ PUNCT punct I
# that DET nsubj is
# is AUX relcl I
# to PART aux say
# say VERB xcomp is
# , PUNCT punct I
#
#  SPACE  ,
# my DET poss soul
# soul NOUN appos I
# by ADP prep am
# which DET pobj by
# I PRON nsubj am
# am AUX relcl soul
# what PRON attr am
# I PRON nsubj am
# am AUX ccomp am
# ] PUNCT punct soul
# , PUNCT punct is
# is AUX ccomp is
# entirely ADV advmod distinct
# and CCONJ cc entirely
# absolutely ADV conj entirely
#
#  SPACE  absolutely
# distinct ADJ acomp is
# from ADP prep distinct
# my DET poss body
# body NOUN pobj from
# , PUNCT punct is
# and CCONJ cc is
# can VERB aux exist
# exist VERB conj is
# without ADP prep exist
# it PRON pobj without
# . PUNCT punct possess
#
#
#  SPACE  .
# And CCONJ cc from
# also ADV advmod from
# from ADP prep is
# the DET det fact
# fact NOUN pobj from
# that SCONJ mark are
# amongst ADP prep are
# these DET det sense
# different ADJ amod sense
# sense NOUN compound perceptions
# - PUNCT punct perceptions
# perceptions NOUN intj amongst
# some DET nsubj are
#
#  SPACE  some
# are AUX acl fact
# very ADV advmod agreeable
# agreeable ADJ acomp are
# to ADP prep agreeable
# me PRON pobj to
# and CCONJ cc me
# others NOUN conj me
# disagreeable ADJ acomp are
# , PUNCT punct is
# it PRON nsubj is
# is AUX ROOT is
# quite ADV advmod certain
#
#  SPACE  quite
# certain ADJ acomp is
# that SCONJ mark receive
# my DET poss body
# body NOUN nsubj inasmuch
# ( PUNCT punct body
# or CCONJ cc body
# rather ADV advmod myself
# myself PRON conj body
# in ADP prep body
# my DET poss entirety
# entirety NOUN pobj in
# , PUNCT punct body
#
#  SPACE  ,
# inasmuch ADJ nsubj receive
# as SCONJ mark formed
# I PRON nsubjpass formed
# am AUX auxpass formed
# formed VERB advcl inasmuch
# of ADP prep formed
# body NOUN pobj of
# and CCONJ cc body
# soul NOUN conj body
# ) PUNCT punct body
# may VERB aux receive
# receive VERB ccomp certain
#
#  SPACE  receive
# different ADJ amod impressions
# impressions NOUN dobj receive
# agreeable ADJ amod impressions
# and CCONJ cc agreeable
# disagreeable ADJ conj agreeable
# from ADP prep disagreeable
# the DET det bodies
#
#  SPACE  the
# other ADJ amod bodies
# bodies NOUN pobj from
# which DET nsubj surround
# surround VERB relcl bodies
# it PRON dobj surround
# . PUNCT punct is
#
#
#  SPACE  .
# But CCONJ cc is
# certainly ADV advmod is
# although SCONJ mark is
# in ADP prep is
# regard NOUN pobj in
# to ADP prep regard
# the DET det body
# dropsical ADJ amod body
# body NOUN pobj to
# it PRON nsubj is
#
#  SPACE  it
# is AUX ROOT is
# only ADV advmod so
# so ADV advmod is
# to PART aux speak
# speak VERB xcomp is
# to PART aux apply
# apply VERB advcl speak
# an DET det term
# extrinsic ADJ amod term
# term NOUN dobj apply
# when ADV advmod say
# we PRON nsubj say
# say VERB advcl speak
#
#  SPACE  say
# that SCONJ mark corrupted
# its DET poss nature
# nature NOUN nsubjpass corrupted
# is AUX auxpass corrupted
# corrupted VERB ccomp say
# , PUNCT punct corrupted
# inasmuch ADJ advmod apart
# as SCONJ advmod apart
# apart ADV advmod corrupted
# from ADP prep apart
# the DET det need
# need NOUN pobj from
#
#  SPACE  need
# to PART aux drink
# drink VERB advcl corrupted
# , PUNCT punct parched
# the DET det throat
# throat NOUN nsubjpass parched
# is AUX auxpass parched
# parched VERB conj is
# ; PUNCT punct is
# yet CCONJ cc is
# in ADP prep is
# regard NOUN pobj in
# to ADP prep regard
# the DET det whole
#
#  SPACE  the
# composite ADJ amod whole
# whole NOUN pobj to
# , PUNCT punct is
# that DET nsubj is
# is AUX conj is
# to PART aux say
# say VERB xcomp is
# , PUNCT punct is
# to ADP intj ,
# the DET det mind
# mind NOUN pobj to
# or CCONJ cc mind
# soul NOUN conj mind
# united VERB acl mind
# to ADP prep united
#
#  SPACE  to
# this DET det body
# body NOUN npadvmod is
# , PUNCT punct is
# it PRON nsubj is
# is AUX ROOT is
# not PART neg is
# a DET det predicate
# purely ADV advmod verbal
# verbal ADJ amod predicate
# predicate NOUN attr is
# , PUNCT punct is
# but CCONJ cc is
# a DET det error
# real ADJ amod error
#
#  SPACE  real
# error NOUN conj is
# of ADP prep error
# nature NOUN pobj of
# , PUNCT punct is
# for ADP mark have
# it PRON nsubj have
# to PART aux have
# have AUX advcl is
# thirst NOUN dobj have
# when ADV advmod be
# drinking NOUN nsubj be
# would VERB aux be
# be AUX advcl have
#
#  SPACE  be
# hurtful ADJ acomp be
# to ADP prep hurtful
# it PRON pobj to
# . PUNCT punct is
#
#
#  SPACE  .
# But CCONJ cc is
# it PRON nsubj is
# is AUX ccomp is
# quite ADV advmod otherwise
# otherwise ADV advmod is
# with ADP prep is
# corporeal NOUN amod objects
# or CCONJ cc corporeal
# extended VERB conj corporeal
# objects NOUN pobj with
# , PUNCT punct is
# for ADP mark is
# there PRON expl is
# is AUX ccomp be
# not PART neg is
# one NUM attr is
# of ADP prep one
# these DET pobj of
#
#  SPACE  these
# imaginable ADJ acomp is
# by ADP prep imaginable
# me PRON pobj by
# which DET dobj divide
# my DET poss mind
# mind NOUN nsubj divide
# can VERB aux divide
# not PART neg divide
# easily ADV advmod divide
# divide VERB advcl is
# into ADP prep divide
#
#  SPACE  into
# parts NOUN pobj into
# , PUNCT punct divide
# and CCONJ cc divide
# which DET dobj recognise
# consequently ADV advmod recognise
# I PRON nsubj recognise
# do AUX aux recognise
# not PART neg recognise
# recognise VERB conj divide
# as SCONJ prep recognise
# being AUX pcomp as
#
#  SPACE  being
# divisible ADJ acomp being
# ; PUNCT punct be
# this DET nsubj be
# would VERB aux be
# be AUX ccomp learned
# sufficient ADJ acomp be
# to PART aux teach
# teach VERB xcomp sufficient
# me PRON dobj teach
# that SCONJ mark is
# the DET det mind
# mind NOUN nsubj is
#
#  SPACE  mind
# or CCONJ cc mind
# soul NOUN conj mind
# of ADP prep soul
# man NOUN pobj of
# is AUX ccomp be
# entirely ADV advmod different
# different ADJ acomp is
# from ADP prep different
# the DET det body
# body NOUN pobj from
# , PUNCT punct learned
# if SCONJ mark had
# I PRON nsubj had
# had AUX advcl learned
#
#  SPACE  had
# not PART neg learned
# already ADV advmod learned
# learned VERB ROOT learned
# it PRON dobj learned
# from ADP prep learned
# other ADJ amod sources
# sources NOUN pobj from
# . PUNCT punct learned
#
#
#  SPACE  .

# %%
for i in range(len(sentences)):
    doc_soul = nlp(sentences[i])
    pos = [(w.text, w.pos_) for w in doc_soul]
    for j in pos:
        if j[1] == 'ADJ':
            print(j[0])
# Out:
# rare
# subtle
# grosser
# true
# more
# unknown
# clear
# distinct
# inasmuch
# unextended
# other
# distinct
# inasmuch
# extended
# unthinking
# certain
# distinct
# different
# agreeable
# disagreeable
# certain
# inasmuch
# different
# agreeable
# disagreeable
# other
# dropsical
# extrinsic
# inasmuch
# composite
# verbal
# real
# hurtful
# imaginable
# divisible
# sufficient
# different
# other

# %%
for i in range(len(sentences)):
    doc = nlp(sentences[i])
    pos = [(w.text, w.pos_) for w in doc]
    for j in pos:
        if j[1] == 'VERB':
            print(j[0])
# Out:
# considered
# nourished
# walked
# felt
# thought
# referred
# stop
# consider
# stop
# imagined
# spread
# Let
# pass
# see
# admit
# speak
# thinks
# say
# shall
# say
# possess
# conjoined
# possess
# say
# can
# exist
# formed
# may
# receive
# surround
# speak
# apply
# say
# corrupted
# drink
# parched
# say
# united
# would
# extended
# can
# divide
# recognise
# would
# teach
# learned

# %%
from spacy import displacy

nlp = spacy.load("en_core_web_sm")
doc_soul = nlp(sample_Soul)
displacy.render(doc_soul, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8d56682b24d3455da3914ba5083194f7-0" class="displacy" width="86150" height="2587.0" direction="ltr" style="max-width: none; height: 2587.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">addition</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">considered</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">nourished,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">walked,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">felt,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">thought,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">referred</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">all</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">these</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">actions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2497.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">soul:</tspan>
#     <tspan class="displacy-tag" dy="2em" fil
