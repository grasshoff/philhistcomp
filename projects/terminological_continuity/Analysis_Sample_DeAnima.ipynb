# %% [markdown]
# ### Preparing and Analysing a Sample Text: Sydney Penner's (2011) English translation of Suárez' *De Anima, Disputation 12, Question 2*

# %% [markdown]
# **3. Analysis (cont.)**

# %%
import pandas as pd
import re

# %%
import spacy

# %%
DeAnima_Soul = open('DeAnima_soul.txt', encoding="utf8")

# %%
sample_Soul = DeAnima_Soul.read()

# %%
from spacy.lang.en import English

raw_text = sample_Soul
nlp = English()
nlp.add_pipe(nlp.create_pipe('sentencizer'))
doc_soul = nlp(raw_text)
sentences = [sent.string.strip() for sent in doc_soul.sents]

# %%
sentences
# Out:
# ['And, of course, having supposed that they are really distinguished from\nthe essence [of the soul], it is much more probable that they are also \n[really] distinguished from each other.',
#  'Sixth, because our soul is the form of the body.',
#  'Therefore, just as other forms\ndepend on the heavens in their operations and follow inﬂuence from it,\nso also our soul and will.',
#  'Seventh, will and sensitive appetite are powers rooted in the same\nsoul.',
#  'For it is the same soul desiring in either case.',
#  'Moreover, the\nsame soul cannot at the same time desire contraries.',
#  'All the ancient pagans who asserted that our soul is material\nand mortal especially erred in this question.',
#  'Just as they posited two gods, one\nthe principle of goods, the other of bads, so also they posited two souls\nin us, one which necessitates to good, the other to bad.',
#  'For these powers are spiritual and of a higher order, for although our soul is the \nform of the body it, nevertheless, is not wholly immersed in the body but is raised \nfrom the body in some of its acts.',
#  'Nor is it repugnant that the same soul desire contraries through different powers, \nespecially if it constrains the inclination of one power through the other power.']

# %%
sentences = [item.replace('\n', " ") for item in sentences]
print (sentences)
# Out:
# ['And, of course, having supposed that they are really distinguished from the essence [of the soul], it is much more probable that they are also  [really] distinguished from each other.', 'Sixth, because our soul is the form of the body.', 'Therefore, just as other forms depend on the heavens in their operations and follow inﬂuence from it, so also our soul and will.', 'Seventh, will and sensitive appetite are powers rooted in the same soul.', 'For it is the same soul desiring in either case.', 'Moreover, the same soul cannot at the same time desire contraries.', 'All the ancient pagans who asserted that our soul is material and mortal especially erred in this question.', 'Just as they posited two gods, one the principle of goods, the other of bads, so also they posited two souls in us, one which necessitates to good, the other to bad.', 'For these powers are spiritual and of a higher order, for although our soul is the  form of the body it, nevertheless, is not wholly immersed in the body but is raised  from the body in some of its acts.', 'Nor is it repugnant that the same soul desire contraries through different powers,  especially if it constrains the inclination of one power through the other power.']

# %%
df = pd.DataFrame(sentences) 
df.columns = ['statements on soul']
df[:10]
# Out:
#                                   statements on soul
# 0  And, of course, having supposed that they are ...
# 1   Sixth, because our soul is the form of the body.
# 2  Therefore, just as other forms depend on the h...
# 3  Seventh, will and sensitive appetite are power...
# 4   For it is the same soul desiring in either case.
# 5  Moreover, the same soul cannot at the same tim...
# 6  All the ancient pagans who asserted that our s...
# 7  Just as they posited two gods, one the princip...
# 8  For these powers are spiritual and of a higher...
# 9  Nor is it repugnant that the same soul desire ...

# %% [markdown]
# #### Manual analysis of statements on soul, indicating challenges for nlp:
#
# 0. *they* are distinguished from the soul. This might be a very important point, but previous matching caused lack of context: we don't know what the pronoun 'they' refers to.
# 1. defining soul *as* form of the body. Focussing only on adjectives and verbs (in direct connection with term 'soul') would miss this definition which, however, seems crucial for an adequate analysis.
# 2. soul depends on operations of the heavens. Also not captured by verbs and adjectives...
# 3. on different powers of the (same) soul, defining will and appetite as powers (functions) of the soul. Also not captured by current method.
# 4. different powers unified by soul's desiring.
# 5. principle of non-contradictory desires
# 6. soul is *not* material and mortal. Including negation as part of verbs/adjeactive (as suggested in "ideal_strategy") is not sufficient for capturing Suarez's rejection: acc. to current method, spacy would assume that Suarez conceives the soul to *be* material and mortal.
# 7. there are *not* two souls in us (claim wrt unity of the soul). Same problem...
# 8. on relation soul/body
# 9. on competing desires of the soul
#
# **conclusion/insight:** method still requires refinement, analysing semantic similarity between adjectives and verbs used in connection with term 'soul' (e.g. in Descartes' and Suárez' writings) would entirely miss the point

# %%
nlp = spacy.load('en_core_web_sm')
# Out:
# C:\Users\sdbra\anaconda3\lib\site-packages\spacy\util.py:271: UserWarning: [W031] Model 'en_core_web_sm' (2.2.5) requires spaCy v2.2 and is incompatible with the current spaCy version (2.3.0). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
doc_soul = nlp(sample_Soul)

# %%
for token in doc_soul:
    print(token, token.pos_, token.dep_, token.head)
# Out:
# And CCONJ cc is
# , PUNCT punct is
# of ADP prep is
# course NOUN pobj of
# , PUNCT punct is
# having VERB aux supposed
# supposed VERB advcl is
# that SCONJ mark distinguished
# they PRON nsubjpass distinguished
# are AUX auxpass distinguished
# really ADV advmod distinguished
# distinguished ADJ ccomp supposed
# from ADP prep distinguished
#
#  SPACE  from
# the DET det essence
# essence NOUN pobj from
# [ PUNCT punct essence
# of ADP prep essence
# the DET det soul
# soul NOUN pobj of
# ] PUNCT punct essence
# , PUNCT punct is
# it PRON nsubj is
# is AUX ROOT is
# much ADV advmod more
# more ADV advmod probable
# probable ADJ acomp is
# that SCONJ mark are
# they PRON nsubj are
# are AUX ccomp is
# also ADV advmod are
#
#  SPACE  also
# [ PUNCT punct distinguished
# really ADV advmod distinguished
# ] PUNCT punct distinguished
# distinguished VERB acomp are
# from ADP prep distinguished
# each DET det other
# other ADJ pobj from
# . PUNCT punct is
#
#
#  SPACE  .
# Sixth INTJ ROOT Sixth
# , PUNCT punct Sixth
# because SCONJ mark is
# our DET poss soul
# soul NOUN nsubj is
# is AUX advcl Sixth
# the DET det form
# form NOUN attr is
# of ADP prep form
# the DET det body
# body NOUN pobj of
# . PUNCT punct Sixth
#
#
#  SPACE  .
# Therefore ADV advmod depend
# , PUNCT punct depend
# just ADV advmod depend
# as SCONJ mark depend
# other ADJ amod forms
# forms NOUN nsubj depend
#
#  SPACE  forms
# depend VERB ROOT depend
# on ADP prep depend
# the DET det heavens
# heavens NOUN pobj on
# in ADP prep heavens
# their DET poss operations
# operations NOUN pobj in
# and CCONJ cc depend
# follow VERB conj depend
# inﬂuence NOUN dobj follow
# from ADP prep follow
# it PRON pobj from
# , PUNCT punct depend
#
#  SPACE  ,
# so ADV cc depend
# also ADV advmod so
# our DET poss soul
# soul NOUN conj depend
# and CCONJ cc soul
# will NOUN conj soul
# . PUNCT punct depend
#
#
#  SPACE  .
# Seventh ADJ npadvmod are
# , PUNCT punct are
# will NOUN aux are
# and CCONJ cc will
# sensitive ADJ amod appetite
# appetite NOUN conj will
# are AUX ROOT are
# powers NOUN attr are
# rooted VERB acl powers
# in ADP prep rooted
# the DET det soul
# same ADJ amod soul
#
#  SPACE  same
# soul NOUN pobj in
# . PUNCT punct are
#
#
#  SPACE  .
# For ADP prep is
# it PRON nsubj is
# is AUX ROOT is
# the DET det soul
# same ADJ amod soul
# soul NOUN attr is
# desiring VERB acl soul
# in ADP prep desiring
# either DET det case
# case NOUN pobj in
# . PUNCT punct is
#
#
#  SPACE  .
# Moreover ADV advmod soul
# , PUNCT punct Moreover
# the DET det soul
#
#  SPACE  the
# same ADJ amod soul
# soul NOUN ROOT soul
# can VERB aux at
# not PART neg at
# at ADP prep soul
# the DET det time
# same ADJ amod time
# time NOUN pobj at
# desire NOUN compound contraries
# contraries NOUN pobj at
# . PUNCT punct soul
#
#
#  SPACE  .
# All DET predet pagans
# the DET det pagans
# ancient ADJ amod pagans
# pagans NOUN ROOT pagans
# who PRON nsubj asserted
# asserted VERB relcl pagans
# that SCONJ mark is
# our DET poss soul
# soul NOUN nsubj is
# is AUX ccomp asserted
# material NOUN attr is
#
#  SPACE  material
# and CCONJ cc is
# mortal PROPN nsubj erred
# especially ADV advmod erred
# erred VERB conj is
# in ADP prep erred
# this DET det question
# question NOUN pobj in
# . PUNCT punct pagans
#
#
#  SPACE  .
# Just ADV advmod posited
# as SCONJ mark posited
# they PRON nsubj posited
# posited VERB ROOT posited
# two NUM nummod gods
# gods NOUN dobj posited
# , PUNCT punct posited
# one NUM npadvmod posited
#
#  SPACE  one
# the DET det principle
# principle NOUN nsubj posited
# of ADP prep principle
# goods NOUN pobj of
# , PUNCT punct principle
# the DET det other
# other ADJ appos principle
# of ADP prep other
# bads NOUN pobj of
# , PUNCT punct posited
# so CCONJ advmod posited
# also ADV advmod posited
# they PRON nsubj posited
# posited VERB ROOT posited
# two NUM nummod souls
# souls NOUN dobj posited
#
#  SPACE  souls
# in ADP prep posited
# us PRON pobj in
# , PUNCT punct posited
# one NUM npadvmod posited
# which DET nsubj necessitates
# necessitates VERB relcl one
# to ADP prep necessitates
# good NOUN pobj to
# , PUNCT punct necessitates
# the DET det other
# other ADJ appos one
# to PART prep other
# bad ADJ amod to
# . PUNCT punct posited
#
#
#  SPACE  .
# For ADP prep are
# these DET det powers
# powers NOUN pobj For
# are AUX ccomp is
# spiritual ADJ acomp are
# and CCONJ cc spiritual
# of ADP conj spiritual
# a DET det order
# higher ADJ amod order
# order NOUN pobj of
# , PUNCT punct are
# for ADP prep are
# although SCONJ mark is
# our DET poss soul
# soul NOUN nsubj is
# is AUX pcomp for
# the DET det form
#
#  SPACE  the
# form NOUN attr is
# of ADP prep form
# the DET det body
# body NOUN pobj of
# it PRON appos body
# , PUNCT punct is
# nevertheless ADV advmod is
# , PUNCT punct is
# is AUX auxpass immersed
# not PART neg immersed
# wholly ADV advmod immersed
# immersed VERB ROOT immersed
# in ADP prep immersed
# the DET det body
# body NOUN pobj in
# but CCONJ cc immersed
# is AUX auxpass raised
# raised VERB conj immersed
#
#  SPACE  raised
# from ADP prep raised
# the DET det body
# body NOUN pobj from
# in ADP prep raised
# some DET pobj in
# of ADP prep some
# its DET poss acts
# acts NOUN pobj of
# . PUNCT punct immersed
#
#
#  SPACE  .
# Nor CCONJ cc is
# is AUX ROOT is
# it PRON nsubj is
# repugnant ADJ acomp is
# that SCONJ intj repugnant
# the DET det soul
# same ADJ amod soul
# soul NOUN nsubj contraries
# desire VERB compound contraries
# contraries NOUN intj that
# through ADP prep contraries
# different ADJ amod powers
# powers NOUN pobj through
# , PUNCT punct contraries
#
#  SPACE  ,
# especially ADV advmod constrains
# if SCONJ mark constrains
# it PRON nsubj constrains
# constrains VERB ROOT constrains
# the DET det inclination
# inclination NOUN dobj constrains
# of ADP prep inclination
# one NUM nummod power
# power NOUN pobj of
# through ADP prep constrains
# the DET det power
# other ADJ amod power
# power NOUN pobj through
# . PUNCT punct constrains

# %%
for i in range(len(sentences)):
    doc_soul = nlp(sentences[i])
    pos = [(w.text, w.pos_) for w in doc_soul]
    for j in pos:
        if j[1] == 'ADJ':
            print(j[0])
# Out:
# distinguished
# probable
# other
# Sixth
# other
# Seventh
# sensitive
# same
# same
# same
# same
# ancient
# material
# other
# other
# bad
# spiritual
# higher
# repugnant
# same
# different
# other

# %%
for i in range(len(sentences)):
    doc = nlp(sentences[i])
    pos = [(w.text, w.pos_) for w in doc]
    for j in pos:
        if j[1] == 'VERB':
            print(j[0])
# Out:
# having
# supposed
# distinguished
# depend
# follow
# rooted
# desiring
# can
# asserted
# erred
# posited
# posited
# necessitates
# immersed
# raised
# desire
# constrains

# %%
from spacy import displacy

nlp = spacy.load("en_core_web_sm")
doc_soul = nlp(sample_Soul)
displacy.render(doc_soul, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="cc451fa5f4f44d9891726354d51547aa-0" class="displacy" width="41000" height="1712.0" direction="ltr" style="max-width: none; height: 1712.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">And,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">course,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">having</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">supposed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">they</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">really</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">distinguished</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">essence [</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">soul],</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">much</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">more</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">probable</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">they</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">also</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">
# [</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">really]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">distinguished</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">each</tspan>
#     <tspan class="displacy-
