# %%
from scrape_resultat import nurse_text
import numpy as np

# %%
import pandas as pd
import re
# I don't need pandas for [9], but I was thinking that I should create a table using pandas as was done with the "pd.DataFrame.from_dict(post1).drop(['title'], axis=1)" code. But somehow this code extracts the wrong titles.

# %% [raw]
# for i in range(0, len(nurse_text)):
#     print('post title ', i, ': ', nurse_text[i]['title'])
#     for comment in nurse_text[i]['comments']:
#         print('comment (', nurse_text[i]['title'], '):',  comment)

# %%
df = pd.DataFrame(nurse_text)

# %%
lst_col = 'comments'

alle = pd.DataFrame({
      col:np.repeat(df[col].values, df[lst_col].str.len())
      for col in df.columns.drop(lst_col)}
    ).assign(**{lst_col:np.concatenate(df[lst_col].values)})[df.columns]

# %%
alle['number'] = alle["comments"].str.extract("(\d{9})", expand=False)
number

# %%
alle['comments'] = [re.sub('(>{0,2}\d{9}>{0,2})', "", i) for i in alle.comments]

# %%
alle
# Out:
#                                                 comments  \
# 0      \n                    Did everyone just sudden...
# 1      \n                    /pol/ : do you agree wit...
# 2       why does she dislike the white areas of Georg...
# 3       As a Nurse, shouldn't she be trying to provid...
# 4       Summa Cum Laude and she still can't speak pro...
# 5       makes ya think why they don't and only do it ...
# 6       Shes a nigger psycho, she has a mindless impu...
# 7       It can’t even form a complete sentence. It ca...
# 8                                    it's latin, retard
# 9       lol hate to brake it to ya honey but sav and ...
# 10      Yes.Nothing will change until the complacent ...
# 11                                     Yes. Accelerate.
# 12      sued this fat jew who I will prob end up gutt...
# 13                                                 lmao
# 14      I thought encouraging violence was against th...
# 15      that sentenceEbonics is unironically easier t...
# 16      Anyone got the hospital she works at? Let's p...
# 17      I thought encouraging violence was against th...
# 18      I agree with her. make sure they do it in a s...
# 19            Anyone got the hospital she works at?Hmmm
# 20                   sounds a tad violent there twatter
# 21      Ugh Antifa only stirs shit up in gun free zon...
# 22                                       Gwinnett>white
# 23      Send this to her job and get her ass fired. T...
# 24      Gosh it would be unfortunate if her employer ...
# 25      doesn't know niggers only need a pulse to gra...
# 26                                     Sumo's coom loud
# 27                           Report her to her employer
# 28      go get shot What a stupid bitch. Report here ...
# 29                                        Fuck niggers.
# ...                                                  ...
# 10184   Im just funin you. You okay? Don't take it al...
# 10185                      I'll be fine. I hate people.
# 10186   I had a dream China contains it buts its diff...
# 10187   I guesss so, but I’m lonely and I’m going to ...
# 10188   Metokur livehttps://www.youtube.com/watch?v=D...
# 10189   Hi, it's going to kill 90 percent of the plan...
# 10190   Lousy leaf, go away. Animals are based, you a...
# 10191        great vidya. he's a dead man unfortunately
# 10192                                         indeed, F
# 10193                              Samefagging yourself
# 10194   #CoronaVirus - WATCH (compilation) people col...
# 10195
# 10196   Maybe translate it retard? I don't speak Chin...
# 10197               nah it's cool dude, just veneration
# 10198   I know this is bait, but different utility, l...
# 10199          Best meds to get now while I still can ?
# 10200   Why is no one talking about this: https://you...
# 10201   Bro you need to buy a new VPN, this is just e...
# 10202   Just ordered a mask set. I usually drive to w...
# 10203  \nhttps://www.youtube.com/watch?v=yQflXs0jZ9w&...
# 10204   taken from other postI will try to translate ...
# 10205   Please send mask, goggles, and clothes to Wuh...
# 10206                           TAKE YOUR MEDS, RETARD.
# 10207   If what she says is true we are all dead for ...
# 10208   https://www.reddit.com/r/youtubehaiku/comment...
# 10209
# 10210                                             Good.
# 10211                          Nice larp. Fake and gay.
# 10212       You have a sticky, learn to use the catalog
# 10213                      filmed in a studio in taiwan
#
#                                                    title     number
# 0                                            NURSE HEROS        NaN
# 1      * QUESTION * Do you agree with this nurse, to ...        NaN
# 2      * QUESTION * Do you agree with this nurse, to ...        NaN
# 3      * QUESTION * Do you agree with this nurse, to ...        NaN
# 4      * QUESTION * Do you agree with this nurse, to ...        NaN
# 5      * QUESTION * Do you agree with this nurse, to ...  259578216
# 6      * QUESTION * Do you agree with this nurse, to ...  259578345
# 7      * QUESTION * Do you agree with this nurse, to ...  259578216
# 8      * QUESTION * Do you agree with this nurse, to ...  259578613
# 9      * QUESTION * Do you agree with this nurse, to ...  259578216
# 10     * QUESTION * Do you agree with this nurse, to ...  259578216
# 11     * QUESTION * Do you agree with this nurse, to ...        NaN
# 12     * QUESTION * Do you agree with this nurse, to ...  259578923
# 13     * QUESTION * Do you agree with this nurse, to ...  259578883
# 14     * QUESTION * Do you agree with this nurse, to ...  259578216
# 15     * QUESTION * Do you agree with this nurse, to ...  259578216
# 16     * QUESTION * Do you agree with this nurse, to ...  259578216
# 17     * QUESTION * Do you agree with this nurse, to ...  259579561
# 18     * QUESTION * Do you agree with this nurse, to ...        NaN
# 19     * QUESTION * Do you agree with this nurse, to ...  259579821
# 20     * QUESTION * Do you agree with this nurse, to ...  259578216
# 21     * QUESTION * Do you agree with this nurse, to ...  259578216
# 22     * QUESTION * Do you agree with this nurse, to ...  259578216
# 23     * QUESTION * Do you agree with this nurse, to ...  259578216
# 24     * QUESTION * Do you agree with this nurse, to ...  259578216
# 25     * QUESTION * Do you agree with this nurse, to ...  259578613
# 26     * QUESTION * Do you agree with this nurse, to ...  259578613
# 27     * QUESTION * Do you agree with this nurse, to ...  259578572
# 28     * QUESTION * Do you agree with this nurse, to ...  259578216
# 29     * QUESTION * Do you agree with this nurse, to ...  259578216
# ...                                                  ...        ...
# 10184                      90K INFECTED EXPOSED BY NURSE  240909811
# 10185                      90K INFECTED EXPOSED BY NURSE        NaN
# 10186                      90K INFECTED EXPOSED BY NURSE        NaN
# 10187                      90K INFECTED EXPOSED BY NURSE  240909975
# 10188                      90K INFECTED EXPOSED BY NURSE        NaN
# 10189                      90K INFECTED EXPOSED BY NURSE        NaN
# 10190                      90K INFECTED EXPOSED BY NURSE  240884112
# 10191                      90K INFECTED EXPOSED BY NURSE  240909950
# 10192                      90K INFECTED EXPOSED BY NURSE  240910542
# 10193                      90K INFECTED EXPOSED BY NURSE  240892173
# 10194                      90K INFECTED EXPOSED BY NURSE  240909878
# 10195                      90K INFECTED EXPOSED BY NURSE  240881084
# 10196                      90K INFECTED EXPOSED BY NURSE  240879713
# 10197                      90K INFECTED EXPOSED BY NURSE  240884370
# 10198                      90K INFECTED EXPOSED BY NURSE  240883171
# 10199                      90K INFECTED EXPOSED BY NURSE        NaN
# 10200                      90K INFECTED EXPOSED BY NURSE        NaN
# 10201                      90K INFECTED EXPOSED BY NURSE  240892173
# 10202                      90K INFECTED EXPOSED BY NURSE        NaN
# 10203  Nurse in Wuhan states around 90,000 people are...        NaN
# 10204  Nurse in Wuhan states around 90,000 people are...        NaN
# 10205  Nurse in Wuhan states around 90,000 people are...  240820411
# 10206  Nurse in Wuhan states around 90,000 people are...  240820374
# 10207  Nurse in Wuhan states around 90,000 people are...  240820374
# 10208  Nurse in Wuhan states around 90,000 people are...        NaN
# 10209  Nurse in Wuhan states around 90,000 people are...  240820374
# 10210  Nurse in Wuhan states around 90,000 people are...  240820374
# 10211  Nurse in Wuhan states around 90,000 people are...  240820374
# 10212  Nurse in Wuhan states around 90,000 people are...  240820374
# 10213  Nurse in Wuhan states around 90,000 people are...  240820374
#
# [10214 rows x 3 columns]
