# %%
from scrape_resultat import nurse_text
import numpy as np

# %%
import pandas as pd
import re

# %% [raw]
# for i in range(0, len(nurse_text)):
#     print('post title ', i, ': ', nurse_text[i]['title'])
#     for comment in nurse_text[i]['comments']:
#         print('comment (', nurse_text[i]['title'], '):',  comment)

# %%
df = pd.DataFrame(nurse_text)

# %%
lst_col = 'comments'

alle = pd.DataFrame({
      col:np.repeat(df[col].values, df[lst_col].str.len())
      for col in df.columns.drop(lst_col)}
    ).assign(**{lst_col:np.concatenate(df[lst_col].values)})[df.columns]

# %%
alle['number'] = alle["comments"].str.extract("(\d{9})", expand=False)

# %%
alle['comments'] = [re.sub('(>{0,2}\d{9}>{0,2})', "", i) for i in alle.comments]
alle['comments'] =  [i.replace('\n ', ' ').replace('\n', ' ') for i in alle.comments]

# %%
alle[:10]
# Out:
#                                             comments  \
# 0                      Did everyone just suddenly...
# 1                      /pol/ : do you agree with ...
# 2   why does she dislike the white areas of Georg...
# 3   As a Nurse, shouldn't she be trying to provid...
# 4   Summa Cum Laude and she still can't speak pro...
# 5   makes ya think why they don't and only do it ...
# 6   Shes a nigger psycho, she has a mindless impu...
# 7   It can’t even form a complete sentence. It ca...
# 8                                it's latin, retard
# 9   lol hate to brake it to ya honey but sav and ...
#
#                                                title     number
# 0                                        NURSE HEROS        NaN
# 1  * QUESTION * Do you agree with this nurse, to ...        NaN
# 2  * QUESTION * Do you agree with this nurse, to ...        NaN
# 3  * QUESTION * Do you agree with this nurse, to ...        NaN
# 4  * QUESTION * Do you agree with this nurse, to ...        NaN
# 5  * QUESTION * Do you agree with this nurse, to ...  259578216
# 6  * QUESTION * Do you agree with this nurse, to ...  259578345
# 7  * QUESTION * Do you agree with this nurse, to ...  259578216
# 8  * QUESTION * Do you agree with this nurse, to ...  259578613
# 9  * QUESTION * Do you agree with this nurse, to ...  259578216

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
# I used the first half of the scrape because the nlp only processes 1000000 strings and nurse_text has 1444217.
length = len(nurse_text)
middle_index = length//2
first_half = nurse_text[:middle_index]

# %%
doc3 = nlp(str(first_half))

# %%
from spacy.matcher import PhraseMatcher
matcher = PhraseMatcher(nlp.vocab)
phrase_list = ['nurse', 'bitch', 'hero']
phrase_patterns = [nlp(text) for text in phrase_list]
matcher.add("nurse_pattern", None, *phrase_patterns)
found_matches = matcher(doc3)
print(found_matches)
# Out:
# [(9880432912405939014, 85, 86), (9880432912405939014, 728, 729), (9880432912405939014, 854, 855), (9880432912405939014, 1404, 1405), (9880432912405939014, 1408, 1409), (9880432912405939014, 1565, 1566), (9880432912405939014, 1816, 1817), (9880432912405939014, 2312, 2313), (9880432912405939014, 2383, 2384), (9880432912405939014, 2524, 2525), (9880432912405939014, 4602, 4603), (9880432912405939014, 5732, 5733), (9880432912405939014, 6237, 6238), (9880432912405939014, 6297, 6298), (9880432912405939014, 6727, 6728), (9880432912405939014, 7178, 7179), (9880432912405939014, 7225, 7226), (9880432912405939014, 7246, 7247), (9880432912405939014, 7446, 7447), (9880432912405939014, 7467, 7468), (9880432912405939014, 7594, 7595), (9880432912405939014, 8352, 8353), (9880432912405939014, 8428, 8429), (9880432912405939014, 8643, 8644), (9880432912405939014, 8943, 8944), (9880432912405939014, 8970, 8971), (9880432912405939014, 9016, 9017), (9880432912405939014, 9122, 9123), (9880432912405939014, 9176, 9177), (9880432912405939014, 9455, 9456), (9880432912405939014, 9596, 9597), (9880432912405939014, 9821, 9822), (9880432912405939014, 9856, 9857), (9880432912405939014, 9980, 9981), (9880432912405939014, 10220, 10221), (9880432912405939014, 10251, 10252), (9880432912405939014, 10520, 10521), (9880432912405939014, 10602, 10603), (9880432912405939014, 10638, 10639), (9880432912405939014, 10651, 10652), (9880432912405939014, 11085, 11086), (9880432912405939014, 11428, 11429), (9880432912405939014, 11506, 11507), (9880432912405939014, 11650, 11651), (9880432912405939014, 12155, 12156), (9880432912405939014, 12236, 12237), (9880432912405939014, 12302, 12303), (9880432912405939014, 12593, 12594), (9880432912405939014, 12631, 12632), (9880432912405939014, 12688, 12689), (9880432912405939014, 12804, 12805), (9880432912405939014, 12883, 12884), (9880432912405939014, 12886, 12887), (9880432912405939014, 12903, 12904), (9880432912405939014, 12927, 12928), (9880432912405939014, 12965, 12966), (9880432912405939014, 13104, 13105), (9880432912405939014, 13167, 13168), (9880432912405939014, 13794, 13795), (9880432912405939014, 13856, 13857), (9880432912405939014, 13996, 13997), (9880432912405939014, 14313, 14314), (9880432912405939014, 14578, 14579), (9880432912405939014, 14711, 14712), (9880432912405939014, 14837, 14838), (9880432912405939014, 14873, 14874), (9880432912405939014, 14906, 14907), (9880432912405939014, 15414, 15415), (9880432912405939014, 15591, 15592), (9880432912405939014, 16061, 16062), (9880432912405939014, 16105, 16106), (9880432912405939014, 16313, 16314), (9880432912405939014, 17028, 17029), (9880432912405939014, 17154, 17155), (9880432912405939014, 17327, 17328), (9880432912405939014, 17747, 17748), (9880432912405939014, 17871, 17872), (9880432912405939014, 17996, 17997), (9880432912405939014, 18001, 18002), (9880432912405939014, 18072, 18073), (9880432912405939014, 18131, 18132), (9880432912405939014, 18462, 18463), (9880432912405939014, 18582, 18583), (9880432912405939014, 18840, 18841), (9880432912405939014, 18947, 18948), (9880432912405939014, 19333, 19334), (9880432912405939014, 19366, 19367), (9880432912405939014, 19686, 19687), (9880432912405939014, 19825, 19826), (9880432912405939014, 20021, 20022), (9880432912405939014, 20073, 20074), (9880432912405939014, 20089, 20090), (9880432912405939014, 20212, 20213), (9880432912405939014, 20248, 20249), (9880432912405939014, 20533, 20534), (9880432912405939014, 20606, 20607), (9880432912405939014, 20753, 20754), (9880432912405939014, 20842, 20843), (9880432912405939014, 21513, 21514), (9880432912405939014, 21648, 21649), (9880432912405939014, 21659, 21660), (9880432912405939014, 21698, 21699), (9880432912405939014, 21709, 21710), (9880432912405939014, 21743, 21744), (9880432912405939014, 21748, 21749), (9880432912405939014, 22583, 22584), (9880432912405939014, 22770, 22771), (9880432912405939014, 24224, 24225), (9880432912405939014, 24298, 24299), (9880432912405939014, 24386, 24387), (9880 ...

# %%
sents = [sent for sent in doc3.sents]

# %%
# Show the 1st sentence, which contains a match
for exempli in sents:
    if found_matches[0][1] < exempli.end:
        print(exempli)
        break
# Out:
# Do you agree with this nurse, to burn down only White Cities ??',
