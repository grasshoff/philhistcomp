# %% [markdown]
# ### Testing OCR on two extracts of Ockham's and Suárez' original Latin writings

# %% [markdown]
# **0. display available languages**

# %%
from tesserocr import PyTessBaseAPI
with PyTessBaseAPI(path=r'C:\Users\sdbra\Documents\tesserocr-master\tessdata_best-master/.', lang='eng') as api:
    print(api.GetAvailableLanguages())
# Out:
# ['afr', 'amh', 'ara', 'asm', 'aze', 'aze_cyrl', 'bel', 'ben', 'bod', 'bos', 'bre', 'bul', 'cat', 'ceb', 'ces', 'chi_sim', 'chi_sim_vert', 'chi_tra', 'chi_tra_vert', 'chr', 'cos', 'cym', 'dan', 'deu', 'div', 'dzo', 'ell', 'eng', 'enm', 'epo', 'est', 'eus', 'fao', 'fas', 'fil', 'fin', 'fra', 'frk', 'frm', 'fry', 'gla', 'gle', 'glg', 'grc', 'guj', 'hat', 'heb', 'hin', 'hrv', 'hun', 'hye', 'iku', 'ind', 'isl', 'ita', 'ita_old', 'jav', 'jpn', 'jpn_vert', 'kan', 'kat', 'kat_old', 'kaz', 'khm', 'kir', 'kmr', 'kor', 'kor_vert', 'lao', 'lat', 'lav', 'lit', 'ltz', 'mal', 'mar', 'mkd', 'mlt', 'mon', 'mri', 'msa', 'mya', 'nep', 'nld', 'nor', 'oci', 'ori', 'osd', 'pan', 'pol', 'por', 'pus', 'que', 'ron', 'rus', 'san', 'script/Arabic', 'script/Armenian', 'script/Bengali', 'script/Canadian_Aboriginal', 'script/Cherokee', 'script/Cyrillic', 'script/Devanagari', 'script/Ethiopic', 'script/Fraktur', 'script/Georgian', 'script/Greek', 'script/Gujarati', 'script/Gurmukhi', 'script/HanS', 'script/HanS_ve
# ...

# %% [markdown]
# **1.1 OCR on small extract of one page of Ockham's Ordinatio**

# %%
from tesserocr import PyTessBaseAPI

with PyTessBaseAPI(path=r'C:\Users\sdbra\Documents\tesserocr-master\tessdata_best-master/.', lang='lat') as api:
    api.SetImageFile('sample_Ockham_LT.jpg')
    print(api.GetUTF8Text())
    
    print(api.AllWordConfidences())
# Out:
# Per idem ad aliud? dico quod ista distinctio attributorum,
# propric loquendo et de virtute sermonis, accipitur ex parte ipsorum
# attributorum absolute et secundum se, nec ex hoc sequitur quod
# distinguuntur realiter, quia non sunt realiter in Deo, et ita ex distinc-
# tionc illorum nulla sequitur distinctio realis in Deo. Concedo ta-
# men quod si non essent aliqua distincta realiter vel in Deo vel
# extra non possent attributa dici distincta. Sed si essent distincta
# et importarent aliquid quod est realiter divina essentia essent pure
# synonyma. Et ita concedo quod omnia attributa vel connotant
# aliqua. distincta realiter vel sunt commumia aliquibus distinctis
# realiter.
#
# ...

# %% [markdown]
# results: works fine. Question: for language-parameter, what's the difference between **'lat'**, **'script/Latin'**, and **'srp_latn'**?

# %% [markdown]
# **1.1.1 lang-parameter = script/Latin**

# %%
from tesserocr import PyTessBaseAPI

with PyTessBaseAPI(path=r'C:\Users\sdbra\Documents\tesserocr-master\tessdata_best-master/.', lang='script/Latin') as api:
    api.SetImageFile('sample_Ockham_LT.jpg')
    print(api.GetUTF8Text())
    
    print(api.AllWordConfidences())
# Out:
# Per idem ad aliud? dico quod ista distinctio attributorum,
# propric loquendo et de virtute sermonis, accipitur ex parte ipsorum
# attributorum absolute et secundum se, nec ex hoc sequitur quod
# distinguuntur realiter, quia non sunt realiter in Deo, et ita ex distinc-
# tionc illorum nulla sequitur distinctio realis in Deo. Concedo ta-
# men quod si non essent aliqua distincta realiter vel in Deo vel
# extra non possent attributa dici distincta. Sed si essent distincta
# et importarent aliquid quod est realiter divina essentia essent pure
# synonyma. Et ita concedo quod omnia attributa vel connotant
# aliqua distincta realiter vel sunt communia aliquibus distinctis
# realiter.
#
# ...

# %% [markdown]
# result: slightly (but not significantly) more accurate (94,7 on average) compared to 'latin' (92,6). possible assumption: latin only for latin language, latin script for all languages with latin script - but if so, why is latin script more accurate?

# %% [markdown]
# **1.1.2 lang-parameter = srp_latn** (acc. to tesseract manual page, srp_latn stands for "serbian-latin" (??), source: https://bit.ly/3kAbhVo)

# %%
from tesserocr import PyTessBaseAPI

with PyTessBaseAPI(path=r'C:\Users\sdbra\Documents\tesserocr-master\tessdata_best-master/.', lang='srp_latn') as api:
    api.SetImageFile('sample_Ockham_LT.jpg')
    print(api.GetUTF8Text())
    
    print(api.AllWordConfidences())
# Out:
# Per idem ad aliaud? dico quod ista distinctio attributorum,
# propric loquendo et de virtute sermonis, accipitur ex parte ipsorum
# attributorum absolute ct sccundum se, nec ex hoc sequitur quod
# distinguuntur realiter, quia non sunt realiter in Deo, et ita ex distinc-
# tionc iliorum nulla scquitur distinctio realis m Deo. Concedo ta-
# men quod si non essent aliqua distincta realiter vel in Deo vel
# extra non posscnt attributa dici distincta. Sed si essent distincta
# ct importarcnt aliquid quod est realiter divina essentia essent pure
# synonyma. Et ita concedo quod omnia attributa vel connotant
# aliqua distincta rcalitcr vel sunt communia aliquibus distinctis
# realiter.
#
# ...

# %% [markdown]
# **1.2 OCR on extract (2 double-pages) of Ockham's Ordinatio** (source: Opera philosophica et theologica, Stephanus Brown (ed.), Franciscan Institute Publications, St. Bonaventure University, pp.70-73, *my own scan*)

# %%
# %%time

from tesserocr import PyTessBaseAPI

images = [r'C:\Users\sdbra\Documents\tesserocr-master\data\output\sample_Ockham_LT\aca7cf09-918d-41b7-8622-860a61f7620c-2.jpg', r'C:\Users\sdbra\Documents\tesserocr-master\data\output\sample_Ockham_LT\aca7cf09-918d-41b7-8622-860a61f7620c-3.jpg']

with PyTessBaseAPI(path=r'C:\Users\sdbra\Documents\tesserocr-master\tessdata_best-master/.', psm=1, lang='lat') as api:
    for img in images:
        api.SetImageFile(img)
        
        print(api.GetUTF8Text())
        
        print(api.AllWordConfidences())
# Out:
# 70 LIBER I DIST. 2 Q. II
#
# conveniunt puncto, et dextrum et sinistrum quae conveniunt
# columnae, quia possunt esse quidam conceptus communes prae-
# dicabiles in quid de illo uno simplicissimo. Si tamen intelligeret
# illa opinio quod nisi essent aliqua distincta realiter ad. quae divina
# essentia posset comparari vel quibus ct divinae essentiae possent
# esse aliqua. communia, nullo modo possent attributa distingui
# 8 et esse attributa distincta $| nec se ipsis nec quibuscumque aliis,
# quia, sicut dictum est alias!, a rc simplici non possunt formari
# diversi conceptus simplices et proprii praedicabiles in. quid.
#
# Per idem ad aliud? dico quod ista distinctio attributorum,
# proprie loquendo et de virtute sermonis, accipitur ex parte ipsorum
# atttibutorum absolute et secundum se, nec ex hoc sequitur quod
# distinguuntur realiter, quia non sunt realiter in Deo, et ita ex distinc-
# tionc illorum nulla sequitur distinctio realis in Deo. Concedo ta-
# ...

# %% [markdown]
# results: medium accuracy (89,1% average word confidence), but maybe only because of massive footnotes?

# %% [markdown]
# **2.1 OCR on small extract of one page of Suárez' Disputationes Metaphysicae**

# %%
from tesserocr import PyTessBaseAPI

with PyTessBaseAPI(path=r'C:\Users\sdbra\Documents\tesserocr-master\tessdata_best-master/.', lang='lat') as api:
    api.SetImageFile('sample_Suarez_LT.jpg')
    print(api.GetUTF8Text())
    
    print(api.AllWordConfidences())
# Out:
# Conuerio prasontis tractationis cum pre-
# anissis. — Hc est seeunda principalis pars
# hujus operis; in qua postquam in priori de
# communi conceptu entis, illiusque proprie-
# tatibus, que de illo reciproce dicuntur, trac-
# tatum est, ad definitas rationes entium des-
# cendere, quantum formale objectum, et abs-
# traclio hujus scientie permittit, necessarium
# est. Hoc autem non potest commodius fieri,
# quam per divisiones varias ipsius entis, et
# membrorum ejus, corumqne exactam consi-
# derationem, Diximus autem in superioribus,
# disp. 4, sect. 4, primam et maxime essentialem
# divisionem entis esse in finitum et infinitum
# Secundum essentiam seu in ratione entis,quod
# solum est proprie et simpliciter infinitum;
# et ideo ab hac divisione partem hanc inchoa-
# mus, sub qua comprehendemus nonnullas
# alias, que reipsa cum hac coincidunt, quam-
# vis diversis nominibus vel conceptibus a no-
# bis concipiantur et explicentur. Et quoniam
# ...

# %% [markdown]
# results: works fine

# %% [markdown]
# **2.2 OCR on extract (2 double-pages) of Suárez' Disputationes Metaphysicae** (source: Opera omnia, Vivès, pp.2f., pp.40f., *my own scan*)

# %%
# %%time

from tesserocr import PyTessBaseAPI

images = [r'C:\Users\sdbra\Documents\tesserocr-master\data\output\sample_Suarez_LT\bcc2ce05-3f4f-42e0-a093-209c77e5a425-2.jpg', r'C:\Users\sdbra\Documents\tesserocr-master\data\output\sample_Suarez_LT\bcc2ce05-3f4f-42e0-a093-209c77e5a425-3.jpg']

with PyTessBaseAPI(path=r'C:\Users\sdbra\Documents\tesserocr-master\tessdata_best-master/.', psm=1, lang='lat') as api:
    for img in images:
        api.SetImageFile(img)
        
        print(api.GetUTF8Text())
        
        print(api.AllWordConfidences())
# Out:
# luras; quia vero non possumus ea, quz» sunt
# Dei propria, prout in se sunt, concipere, imo
# nec per positivos conceptus simplices ac pro-
# prios Dei, ideo negativis utimur, ut illud ex-
# cellentissimum ens, quod maxime a exteris
# distat, minusque cum illis corvenit, quam
# ipsa inter sese, ab eis separemus et distin-
# guamus, Atque hoc modo conficimus predic-
# tam divisionem, sumendo aliquid, in quo om-
# Dé$ res ereate vol cveabiles inter se conve-
# niunt, et illud à nobiliori quodam ente remo-
# vendo, eo quod excellentiorem gradum es-
# seniiz vol enlitatis habeat ; atque hoe modo
# totam latitadinem entis ad dao illa membra
# revocanius.
#
# Jéesolutio questisnis.
#
# 4. Divisio dicta bona et apprime necessaria.
# — Ex qua declaratione constat primo, divi-
# sionem illàm in re ipsa optimam esse, et
# maxime necessariam. Primum patet, quia
# illa divisio est. adeequata enti ; nullum enim
# ens extra Deum vel creaturas excogitari po-
# ...

# %% [markdown]
# results: medium accuracy (84,2% average word confidence), but again, maybe only because of massive footnotes...

# %% [markdown]
# **3. Salvador Castellote's Latin-Spanish edition of Suárez' De Anima**, one sample page (source: https://bit.ly/36d11i1)

# %%
from tesserocr import PyTessBaseAPI

images = [r'C:\Users\sdbra\Documents\tesserocr-master\sample_Suarez_LT_Castellote.jpg']

with PyTessBaseAPI(path=r'C:\Users\sdbra\Documents\tesserocr-master\tessdata_best-master/.', psm=1, lang='lat') as api:
    for img in images:
        api.SetImageFile(img)
        
        print(api.GetUTF8Text())
        
        print(api.AllWordConfidences())
# Out:
# QUAESTIO 1
#
# Utrum anima sit actus tamquam vera forma substantialis
#
# 1 Placuit in his quaestionibus singulas particulas definitionis [animae]. pI7y
# singillatim disputare, ut dilucidior sit doctrina. Hic ergo genus eius
# 5 investigando quaerimus, an sit actus, et quomodo. Et ratio dubii est,
# quoniam Aristoteles actum dixit esse animam, tamen quasi indecisum.
# reliquit, an sit actus informans, an sit [improprius] actus, ut assistens
# et gubernans. Et videtur sane non esse formam substantialem, nam
# iorma substantialis non supponit integram substantiam constitutam
# 10 quam actuet; at vero anima supponit substantiam completam. Sup-
# ponit enim corpus organicum cuius est actus, ut Aristoteles? inquit.
# Et confirmatur. Nam si anima informaret, eodem modo
# informaret ommes partes; at videmus non ommes partes habere idem
# esse, nec eumdem modum substantiae Contra est. Nam forma
# 15 est quae dat esse; anima autem est quae dat esse viventis; ergo.
#
# ...

# %% [markdown]
# result: medium accuracy (but also: medium quality of jpg-file); numerous footnotes and esp. line numbering pose serious obstacles to possibility of obtaining a reliable (ocr'ed) txt-version

# %% [markdown]
# **4. small extract of one sample page of archived (i.e. digitalised) original version of Suárez' De Anima** (Vivès Edition, source: https://bit.ly/3jh20RO)

# %% [markdown]
# **4.1 turn yellow(-ish) book pages into black-and-white image** (pre-processing in order to improve accuracy)

# %%
from PIL import Image

column = Image.open('sample_Suarez_LT_archive.jpg')
gray = column.convert('L')
blackwhite = gray.point(lambda x: 0 if x < 200 else 255, '1')
blackwhite.save("sample_Suarez_LT_archive_BW.jpg")

# %% [markdown]
# **4.2 OCR on grey-scale version**

# %%
from tesserocr import PyTessBaseAPI

images = [r'C:\Users\sdbra\Documents\tesserocr-master\sample_Suarez_LT_archive_BW.jpg']

with PyTessBaseAPI(path=r'C:\Users\sdbra\Documents\tesserocr-master\tessdata_best-master/.', psm=1, lang='lat') as api:
    for img in images:
        api.SetImageFile(img)
        
        print(api.GetUTF8Text())
        
        print(api.AllWordConfidences())
# Out:
# VTRUM ANIMA SIT FORMA, SEU ACTUS PRIMUS
# SUBSTAN'TIALIS.
#
# A. Duples anime definitio adducitur em
# Avistotele.—Quoniam preter rationalem ani-
# mam, alii sunt animarum gradus : non possu-
# mus, quid sit rationalis anima exponere : nisi
# prius genericam anime rationem et essentiam
# explicemus. Quam rem tractavit Aristoteles,
# lib. 2, de Anima, cap. 1 et 2, ubi duas anime
# definitiones tradidit: una est, Anima est actus
# primus substantialis corporis physice organici
# potentia vitam habentis. Alia est, Anima cst id,
# quo oivisus, sentimus, loco movemur et intelli-
# gimus. De quibus definitionibus et de osten-
# sione, seu demonstratione unius per aliam,
# quam etiam Aristoteles, in dict. cap. 2, tradit,
# expositores ibi, et alii philosophi multa dispu-
# taut: sed quie huie loeo necessaria sunt brevi-
# ter possunt expediri. Circa priorem ergo defi-
# nitionem dno explicanda sunt. Primum, an
# recte constituatur anima sub genere substan-
# ...

# %% [markdown]
# result: poor accuracy (for an extract that does not contain any footnoes, line numbers etc.), thus impossible to work with

# %% [markdown]
# **5. three pages of archived (i.e. digitalised) version of Ochkam's Quodlibeta Septem**

# %% [markdown]
# **5.1 turn pdf into jpeg**

# %%
from pdf2image import convert_from_path

from pdf2image.exceptions import (
 PDFInfoNotInstalledError,
 PDFPageCountError,
 PDFSyntaxError
)

images = convert_from_path(pdf_path=r'C:\Users\sdbra\Documents\tesserocr-master\data\input\Ockham_Quodlibeta_Septem_[sample].pdf', dpi=300, output_folder=r'C:\Users\sdbra\Documents\tesserocr-master\data\output\sample_Ockham_LT_archived', fmt='jpeg')

for i, image in enumerate(images):
    fname = 'sample_Ockham'+str(i)+'.jpeg'
    image.save(fname, "JPEG")

# %% [markdown]
# **5.2 OCR on three sample pages**

# %%
from tesserocr import PyTessBaseAPI

images = [r'C:\Users\sdbra\Documents\tesserocr-master\data\output\sample_Ockham_LT_archived\93e93f72-98f0-4529-9525-a01ca34b22bf-1.jpg', r'C:\Users\sdbra\Documents\tesserocr-master\data\output\sample_Ockham_LT_archived\93e93f72-98f0-4529-9525-a01ca34b22bf-2.jpg', r'C:\Users\sdbra\Documents\tesserocr-master\data\output\sample_Ockham_LT_archived\93e93f72-98f0-4529-9525-a01ca34b22bf-3.jpg' ]

with PyTessBaseAPI(path=r'C:\Users\sdbra\Documents\tesserocr-master\tessdata_best-master/.', psm=1, lang='lat') as api:
    for img in images:
        api.SetImageFile(img)
        
        print(api.GetUTF8Text())
        
        print(api.AllWordConfidences())
# Out:
# 10
#
# 15
#
# QUODLIBET PRIMUM
#
# QUAESTIO 1
#
# UTRUM POSSIT PROBARI PER RATIONEM NATURALEM
# QUOD TANTUM EST UNUS Drus
#
# Quod sic: Quia unius mundi est tantum unus princeps,
# XII Metaphysicae 1; sed potest probari naturali ratione quod tan-
# tum est unus mundus secundum Philosophum, I De
# caelo?; igitur potest probari naturali ratione quod tantum est
# unus princeps; sed ille est Deus; igitur etc.
#
# Ad oppositum: Articulus fidei non potest evidenter
# probari; sed quod tantum sit unus Deus est articulus fidei 5;
# igitur etc.
#
# In ista quaestione primo exponam quid intelligendum
# est per hoc nomen "Deus; secundo, respondebo ad quae-
# stionem.
#
# [PRIMUs ARrICULUS]
#
# Circa primum dico quod hoc nomen '"Deus' potest habere
# diversas descriptiones: una cest quod Deus est aliquid nobilius
#
#
#
# Qvonuszr I. Corr. ABCDEFGKLM.
#
# Quassrio Í. — 1 mg. ACGK, om. BEFLM 13-14 intelligendum est] intelligitur LM,
# inteligo DFZ
#
# ...

# %% [markdown]
# result: poor to medium accuracy, rather unsuitable to work with

# %% [markdown]
# **Summary / Result of all the tests:** it seems rather difficult - almost impossible - to work with the original Latin texts. Hence, I have no other choice but to work with the English translations - which (i) significantly decreases the available data for my computational analysis as most texts have never (or rather: not yet?) been translated into English/German/French, and (ii) means that the results of my analysis have absolutely no value for considerations concerning the history of philosophy (as initially claimed). Instead, I will concentrate on the development of a methode ("a computational approach to the hist. of phil.) and leave its adequate application for future research. As (i) tesseract (or some other OCR-software) are becoming increasingly powerful and (ii) projects concerned with the digitalisation of medieval texts are still running, it seems not unlikey that it will be possible to adequately work with the Latin texts in a couple of years.
