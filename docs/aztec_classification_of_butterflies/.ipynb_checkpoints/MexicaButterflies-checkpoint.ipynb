# %% [markdown]
# # The butterflies of the Florentine Codex

# %% [markdown]
# ### Creating DataFrame

# %%
import pandas as pd
import re

# %% [markdown]
# ### Sentences with spaCy

# %%
import spacy

# %%
papalotl = open('papalotl.txt')
butterflies = papalotl.read()

# %%
from spacy.lang.en import English

raw_text = butterflies
nlp = English()
nlp.add_pipe(nlp.create_pipe('sentencizer'))
doc = nlp(raw_text)
sentences = [sent.string.strip() for sent in doc.sents]

# %%
sentences
# Out:
# ['BUTTERFLY\nWhatever the kind of butterfly, it is long and straight, the abdomen is slender, the neck is constricted.',
#  'lt is fuzzy, like fat; winged.',
#  'Its wings are twofold.',
#  'It has arms, it has legs, it has antennae.',
#  'lt is a flyer, a constant flyer, a flutterer, a sucker of the different flowers, and a sucker of liquid.',
#  'It is fuzzy.',
#  'It trembles, it beats its wings together, it constantly flies.',
#  'It sucks, it sucks liquid.',
#  'It is not solid.',
#  'There are many kinds of butterflies.',
#  'XICALPAPALOTL OR XICALTECONPAPALOTL.',
#  'OR XICALTECON\nIt is somewhat large.',
#  'Its name comes from xicalli [gourd bowl] and papalotl [butterfly ], because it is yellow, it is quite yellow, it is fuzzy .',
#  'And it is painted with black; it is varicolored.',
#  'So it is very beautiful, coveted, desirable, constantly desirable, constantly required.',
#  'It is fragile.',
#  'It yellows, it becomcs painted, it becomes varicolored.',
#  'It breeds, it becomes firm, it develops; it flies constantly.',
#  'TLILPAPALOTL\nIt is similar to - also just the same as - the xicalpapalotl, but black flecked with white.',
#  'Thus its wings are varicolored.',
#  'TLECOCOZPAPALOTL\nIts name is also quappachpapalotl.',
#  'It is called "fireyellow" because it glows, it glistens a little.',
#  'lts body is a little fiery, but it is smoky, tawny.',
#  'It glows, glistens, glistens constantly.',
#  'It is tawny, smoky, smoky yellow.',
#  'It becomes smoky yellow; it turns smoky yellow.',
#  'IZTAC PAPALOTL\nSome are a little large, some average, some quite small.',
#  'They are not really white, only as whitish, only as pale as they are yellow.',
#  'CHIAN PAPALOTL.',
#  'It is somewhat similar to the xicalpapalotl, because it is painted as if sprinkled with chia, flecked everywhere on its body; and its wings are painted, painted with a chia design.',
#  'TEXOPAPALOTL\nSome are large, some tiny; they are not uniform.',
#  'Its name comes from texotli [light blue].',
#  'But it is not really a blue; it is just so rather pale, just so pallid,\njust so yellow as to be livid.',
#  'It is just a light blue hue.',
#  'It takes on a light blue hue; it becomes blue-brown.',
#  'XOCHIPAPALOTL\nSome are large, some small.',
#  'Many kinds of colors are on them, that they are varicolored, much like flowers, of very intricate design, and truly sought after truly wonderful.',
#  'They are o intricate design, sought after, flower-like.',
#  'UAPPAPALOTL\nIt is of average size; its wings are painted chili-red.',
#  'It is also beautiful, also wonderful.',
#  'Amaranth leaves or foliage are also called uappapalotl when the amaranth leaves already become mature, ripe.',
#  'Then they are named uappapalotl, because they become yellow or chili-red.']

# %%
# Get rid of newlines
sentences = [item.replace('\n', " ") for item in sentences]
print (sentences)
# Out:
# ['BUTTERFLY Whatever the kind of butterfly, it is long and straight, the abdomen is slender, the neck is constricted.', 'lt is fuzzy, like fat; winged.', 'Its wings are twofold.', 'It has arms, it has legs, it has antennae.', 'lt is a flyer, a constant flyer, a flutterer, a sucker of the different flowers, and a sucker of liquid.', 'It is fuzzy.', 'It trembles, it beats its wings together, it constantly flies.', 'It sucks, it sucks liquid.', 'It is not solid.', 'There are many kinds of butterflies.', 'XICALPAPALOTL OR XICALTECONPAPALOTL.', 'OR XICALTECON It is somewhat large.', 'Its name comes from xicalli [gourd bowl] and papalotl [butterfly ], because it is yellow, it is quite yellow, it is fuzzy .', 'And it is painted with black; it is varicolored.', 'So it is very beautiful, coveted, desirable, constantly desirable, constantly required.', 'It is fragile.', 'It yellows, it becomcs painted, it becomes varicolored.', 'It breeds, it becomes firm, it develops; it flies constantly.', 'TLILPAPALOTL It is similar to - also just the same as - the xicalpapalotl, but black flecked with white.', 'Thus its wings are varicolored.', 'TLECOCOZPAPALOTL Its name is also quappachpapalotl.', 'It is called "fireyellow" because it glows, it glistens a little.', 'lts body is a little fiery, but it is smoky, tawny.', 'It glows, glistens, glistens constantly.', 'It is tawny, smoky, smoky yellow.', 'It becomes smoky yellow; it turns smoky yellow.', 'IZTAC PAPALOTL Some are a little large, some average, some quite small.', 'They are not really white, only as whitish, only as pale as they are yellow.', 'CHIAN PAPALOTL.', 'It is somewhat similar to the xicalpapalotl, because it is painted as if sprinkled with chia, flecked everywhere on its body; and its wings are painted, painted with a chia design.', 'TEXOPAPALOTL Some are large, some tiny; they are not uniform.', 'Its name comes from texotli [light blue].', 'But it is not really a blue; it is just so rather pale, just so pallid, just so yellow as to be livid.', 'It is just a light blue hue.', 'It takes on a light blue hue; it becomes blue-brown.', 'XOCHIPAPALOTL Some are large, some small.', 'Many kinds of colors are on them, that they are varicolored, much like flowers, of very intricate design, and truly sought after truly wonderful.', 'They are o intricate design, sought after, flower-like.', 'UAPPAPALOTL It is of average size; its wings are painted chili-red.', 'It is also beautiful, also wonderful.', 'Amaranth leaves or foliage are also called uappapalotl when the amaranth leaves already become mature, ripe.', 'Then they are named uappapalotl, because they become yellow or chili-red.']

# %%
df = pd.DataFrame(sentences) 
df
# Out:
#                                                     0
# 0   BUTTERFLY Whatever the kind of butterfly, it i...
# 1                      lt is fuzzy, like fat; winged.
# 2                              Its wings are twofold.
# 3          It has arms, it has legs, it has antennae.
# 4   lt is a flyer, a constant flyer, a flutterer, ...
# 5                                        It is fuzzy.
# 6   It trembles, it beats its wings together, it c...
# 7                          It sucks, it sucks liquid.
# 8                                    It is not solid.
# 9                There are many kinds of butterflies.
# 10               XICALPAPALOTL OR XICALTECONPAPALOTL.
# 11                OR XICALTECON It is somewhat large.
# 12  Its name comes from xicalli [gourd bowl] and p...
# 13   And it is painted with black; it is varicolored.
# 14  So it is very beautiful, coveted, desirable, c...
# 15                                     It is fragile.
# 16  It yellows, it becomcs painted, it becomes var...
# 17  It breeds, it becomes firm, it develops; it fl...
# 18  TLILPAPALOTL It is similar to - also just the ...
# 19                    Thus its wings are varicolored.
# 20  TLECOCOZPAPALOTL Its name is also quappachpapa...
# 21  It is called "fireyellow" because it glows, it...
# 22  lts body is a little fiery, but it is smoky, t...
# 23           It glows, glistens, glistens constantly.
# 24                  It is tawny, smoky, smoky yellow.
# 25    It becomes smoky yellow; it turns smoky yellow.
# 26  IZTAC PAPALOTL Some are a little large, some a...
# 27  They are not really white, only as whitish, on...
# 28                                    CHIAN PAPALOTL.
# 29  It is somewhat similar to the xicalpapalotl, b...
# 30  TEXOPAPALOTL Some are large, some tiny; they a...
# 31          Its name comes from texotli [light blue].
# 32  But it is not really a blue; it is just so rat...
# 33                       It is just a light blue hue.
# 34  It takes on a light blue hue; it becomes blue-...
# 35          XOCHIPAPALOTL Some are large, some small.
# 36  Many kinds of colors are on them, that they ar...
# 37  They are o intricate design, sought after, flo...
# 38  UAPPAPALOTL It is of average size; its wings a...
# 39              It is also beautiful, also wonderful.
# 40  Amaranth leaves or foliage are also called uap...
# 41  Then they are named uappapalotl, because they ...

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(butterflies)

# %%
for token in doc:
    print(token, token.pos_, token.dep_)
# Out:
# BUTTERFLY PROPN ROOT
#
#  SPACE
# Whatever PRON dep
# the DET det
# kind NOUN nsubj
# of ADP prep
# butterfly NOUN pobj
# , PUNCT punct
# it PRON nsubj
# is AUX ccomp
# long ADJ acomp
# and CCONJ cc
# straight ADJ conj
# , PUNCT punct
# the DET det
# abdomen NOUN nsubj
# is AUX ccomp
# slender ADJ acomp
# , PUNCT punct
# the DET det
# neck NOUN nsubjpass
# is AUX auxpass
# constricted VERB ROOT
# . PUNCT punct
# lt PROPN nsubj
# is AUX ccomp
# fuzzy ADJ acomp
# , PUNCT punct
# like SCONJ prep
# fat NOUN pobj
# ; PUNCT punct
# winged VERB ROOT
# . PUNCT punct
# Its PRON poss
# wings NOUN nsubj
# are AUX ROOT
# twofold ADJ acomp
# . PUNCT punct
# It PRON nsubj
# has AUX ccomp
# arms NOUN dobj
# , PUNCT punct
# it PRON nsubj
# has AUX ccomp
# legs NOUN dobj
# , PUNCT punct
# it PRON nsubj
# has AUX ROOT
# antennae NOUN dobj
# . PUNCT punct
# lt PROPN nsubj
# is AUX ROOT
# a DET det
# flyer NOUN attr
# , PUNCT punct
# a DET det
# constant ADJ amod
# flyer NOUN appos
# , PUNCT punct
# a DET det
# flutterer NOUN conj
# , PUNCT punct
# a DET det
# sucker NOUN appos
# of ADP prep
# the DET det
# different ADJ amod
# flowers NOUN pobj
# , PUNCT punct
# and CCONJ cc
# a DET det
# sucker NOUN conj
# of ADP prep
# liquid NOUN pobj
# . PUNCT punct
# It PRON nsubj
# is AUX ROOT
# fuzzy ADJ acomp
# . PUNCT punct
# It PRON nsubj
# trembles VERB ccomp
# , PUNCT punct
# it PRON nsubj
# beats VERB ccomp
# its PRON poss
# wings NOUN dobj
# together ADV advmod
# , PUNCT punct
# it PRON nsubj
# constantly ADV advmod
# flies VERB ROOT
# . PUNCT punct
# It PRON nsubj
# sucks VERB ccomp
# , PUNCT punct
# it PRON nsubj
# sucks VERB ROOT
# liquid ADV advmod
# . PUNCT punct
# It PRON nsubj
# is AUX ROOT
# not PART neg
# solid ADJ acomp
# . PUNCT punct
# There PRON expl
# are AUX ROOT
# many ADJ amod
# kinds NOUN attr
# of ADP prep
# butterflies NOUN pobj
# . PUNCT punct
#
#
#  SPACE
# XICALPAPALOTL PROPN ROOT
# OR CCONJ cc
# XICALTECONPAPALOTL PROPN conj
# . PUNCT punct
# OR CCONJ cc
# XICALTECON PROPN ROOT
#
#  SPACE
# It PRON nsubj
# is AUX ROOT
# somewhat ADV advmod
# large ADJ acomp
# . PUNCT punct
# Its PRON poss
# name NOUN nsubj
# comes VERB ROOT
# from ADP prep
# xicalli PROPN pobj
# [ PUNCT punct
# gourd PROPN compound
# bowl PROPN appos
# ] PUNCT punct
# and CCONJ cc
# papalotl PROPN nmod
# [ PUNCT punct
# butterfly NOUN conj
# ] PUNCT punct
# , PUNCT punct
# because SCONJ mark
# it PRON nsubj
# is AUX advcl
# yellow ADJ acomp
# , PUNCT punct
# it PRON nsubj
# is AUX ccomp
# quite ADV advmod
# yellow ADJ acomp
# , PUNCT punct
# it PRON nsubj
# is AUX conj
# fuzzy ADJ acomp
# . PUNCT punct
# And CCONJ cc
# it PRON nsubjpass
# is AUX auxpass
# painted VERB ccomp
# with ADP prep
# black ADJ pobj
# ; PUNCT punct
# it PRON nsubjpass
# is AUX auxpass
# varicolored VERB ROOT
# . PUNCT punct
# So ADV advmod
# it PRON nsubj
# is AUX ccomp
# very ADV advmod
# beautiful ADJ acomp
# , PUNCT punct
# coveted ADJ acomp
# , PUNCT punct
# desirable ADJ amod
# , PUNCT punct
# constantly ADV advmod
# desirable ADJ conj
# , PUNCT punct
# constantly ADV advmod
# required VERB ROOT
# . PUNCT punct
# It PRON nsubj
# is AUX ROOT
# fragile ADJ acomp
# . PUNCT punct
# It PRON nsubj
# yellows VERB ROOT
# , PUNCT punct
# it PRON nsubj
# becomcs VERB npadvmod
# painted VERB ccomp
# , PUNCT punct
# it PRON nsubj
# becomes VERB conj
# varicolored VERB acomp
# . PUNCT punct
# It PRON nsubj
# breeds VERB ccomp
# , PUNCT punct
# it PRON nsubj
# becomes VERB parataxis
# firm ADJ acomp
# , PUNCT punct
# it PRON nsubj
# develops VERB parataxis
# ; PUNCT punct
# it PRON nsubj
# flies VERB ROOT
# constantly ADV advmod
# . PUNCT punct
#
#
#  SPACE
# TLILPAPALOTL NOUN ROOT
#
#  SPACE
# It PRON nsubj
# is AUX ROOT
# similar ADJ acomp
# to PART prep
# - PUNCT punct
# also ADV advmod
# just ADV advmod
# the DET det
# same ADJ npadvmod
# as SCONJ prep
# - PUNCT punct
# the DET det
# xicalpapalotl NOUN pobj
# , PUNCT punct
# but CCONJ cc
# black ADJ amod
# flecked VERB conj
# with ADP prep
# white ADJ pobj
# . PUNCT punct
# Thus ADV advmod
# its PRON poss
# wings NOUN nsubjpass
# are AUX auxpass
# varicolored VERB ROOT
# . PUNCT punct
#
#
#  SPACE
# TLECOCOZPAPALOTL PROPN ROOT
#
#  SPACE
# Its PRON poss
# name NOUN nsubj
# is AUX ROOT
# also ADV advmod
# quappachpapalotl NOUN acomp
# . PUNCT punct
# It PRON nsubjpass
# is AUX auxpass
# called VERB ccomp
# " PUNCT punct
# fireyellow VERB oprd
# " PUNCT punct
# because SCONJ mark
# it PRON nsubj
# glows VERB advcl
# , PUNCT punct
# it PRON nsubj
# glistens VERB ROOT
# a DET det
# little ADJ dobj
# . PUNCT punct
# lts NOUN compound
# body NOUN nsubj
# is AUX ROOT
# a DET det
# little ADJ amod
# fiery NOUN attr
# , PUNCT punct
# but CCONJ cc
# it PRON nsubj
# is AUX conj
# smoky ADJ acomp
# , PUNCT punct
# tawny PROPN npadvmod
# . PUNCT punct
# It PRON nsubj
# glows VERB ROOT
# , PUNCT punct
# glistens NOUN intj
# , PUNCT punct
# glistens VERB conj
# constantly ADV advmod
# . PUNCT punct
# It PRON nsubj
# is AUX ROOT
# tawny ADJ attr
# , PUNCT punct
# smoky ADJ amod
# , PUNCT punct
# smoky ADJ amod
# yellow ADJ appos
# . PUNCT punct
# It PRON nsubj
# becomes VERB ccomp
# smoky ADJ advmod
# yellow ADJ acomp
# ; PUNCT punct
# it PRON nsubj
# turns VERB ROOT
# smoky ADJ amod
# yellow ADJ acomp
# . PUNCT punct
#
#
#  SPACE
# IZTAC ADJ compound
# PAPALOTL ADJ ROOT
#
#  SPACE
# Some DET nsubj
# are AUX ROOT
# a DET det
# little ADJ advmod
# large ADJ amod
# , PUNCT punct
# some DET det
# average ADJ amod
# , PUNCT punct
# some DET advmod
# quite ADV advmod
# small ADJ acomp
# . PUNCT punct
# They PRON nsubj
# are AUX ROOT
# not PART neg
# really ADV advmod
# white ADJ acomp
# , PUNCT punct
# only ADV advmod
# as SCONJ prep
# whitish ADJ pobj
# , PUNCT punct
# only ADV advmod
# as ADV advmod
# pale ADJ advcl
# as SCONJ mark
# they PRON nsubj
# are AUX advcl
# yellow ADJ acomp
# . PUNCT punct
#
#
#  SPACE
# CHIAN PROPN compound
# PAPALOTL PROPN ROOT
# . PUNCT punct
#
#  SPACE
# It PRON nsubj
# is AUX ROOT
# somewhat ADV advmod
# similar ADJ acomp
# to ADP prep
# the DET det
# xicalpapalotl PROPN pobj
# , PUNCT punct
# because SCONJ mark
# it PRON nsubjpass
# is AUX auxpass
# painted VERB advcl
# as SCONJ mark
# if SCONJ mark
# sprinkled VERB advcl
# with ADP prep
# chia PROPN pobj
# , PUNCT punct
# flecked VERB conj
# everywhere ADV advmod
# on ADP prep
# its PRON poss
# body NOUN pobj
# ; PUNCT punct
# and CCONJ cc
# its PRON poss
# wings NOUN nsubjpass
# are AUX auxpass
# painted VERB conj
# , PUNCT punct
# painted VERB advcl
# with ADP prep
# a DET det
# chia NOUN compound
# design NOUN pobj
# . PUNCT punct
#
#
#  SPACE
# TEXOPAPALOTL PROPN ROOT
#
#  SPACE
# Some DET nsubj
# are AUX ccomp
# large ADJ acomp
# , PUNCT punct
# some DET nsubj
# tiny ADJ acomp
# ; PUNCT punct
# they PRON nsubj
# are AUX ROOT
# not PART neg
# uniform ADJ acomp
# . PUNCT punct
# Its PRON poss
# name NOUN nsubj
# comes VERB ROOT
# from ADP prep
# texotli NOUN pobj
# [ PUNCT punct
# light PROPN amod
# blue ADJ appos
# ] PUNCT punct
# . PUNCT punct
# But CCONJ cc
# it PRON nsubj
# is AUX ccomp
# not PART neg
# really ADV advmod
# a DET det
# blue NOUN attr
# ; PUNCT punct
# it PRON nsubj
# is AUX ROOT
# just ADV advmod
# so ADV advmod
# rather ADV advmod
# pale ADJ acomp
# , PUNCT punct
# just ADV advmod
# so ADV advmod
# pallid ADJ conj
# , PUNCT punct
#
#  SPACE
# just ADV advmod
# so ADV advmod
# yellow ADJ acomp
# as SCONJ mark
# to PART aux
# be AUX xcomp
# livid ADJ acomp
# . PUNCT punct
# It PRON nsubj
# is AUX ROOT
# just ADV advmod
# a DET det
# light ADJ amod
# blue ADJ amod
# hue NOUN attr
# . PUNCT punct
# It PRON nsubj
# takes VERB ccomp
# on ADP prt
# a DET det
# light ADJ amod
# blue ADJ amod
# hue PROPN dobj
# ; PUNCT punct
# it PRON nsubj
# becomes VERB ROOT
# blue ADJ amod
# - PUNCT punct
# brown ADJ acomp
# . PUNCT punct
#
#
#  SPACE
# XOCHIPAPALOTL PROPN ROOT
#
#  SPACE
# Some DET nsubj
# are AUX ROOT
# large ADJ amod
# , PUNCT punct
# some DET det
# small ADJ acomp
# . PUNCT punct
# Many ADJ amod
# kinds NOUN nsubj
# of ADP prep
# colors NOUN pobj
# are AUX ROOT
# on ADP prep
# them PRON pobj
# , PUNCT punct
# that SCONJ mark
# they PRON nsubjpass
# are AUX auxpass
# varicolored VERB advcl
# , PUNCT punct
# much ADV advmod
# like SCONJ prep
# flowers NOUN pobj
# , PUNCT punct
# of ADP prep
# very ADV advmod
# intricate ADJ amod
# design NOUN pobj
# , PUNCT punct
# and CCONJ cc
# truly ADV advmod
# sought VERB conj
# after ADP prep
# truly ADV advmod
# wonderful ADJ pobj
# . PUNCT punct
# They PRON nsubj
# are AUX ROOT
# o ROOT
# uappapalotl PROPN oprd
# when ADV advmod
# the DET det
# amaranth ADJ compound
# leaves NOUN nsubj
# already ADV advmod
# become VERB advcl
# mature ADJ amod
# , PUNCT punct
# ripe ADJ acomp
# . PUNCT punct
# Then ADV advmod
# they PRON nsubjpass
# are AUX auxpass
# named VERB ROOT
# uappapalotl PROPN oprd
# , PUNCT punct
# because SCONJ mark
# they PRON nsubj
# become VERB advcl
# yellow ADJ acomp
# or CCONJ cc
# chili NOUN compound
# - PUNCT punct
# red NOUN conj
# . PUNCT punct

# %% [markdown]
# ### How many terms?

# %%
len(re.findall('papalotl', butterflies))
# Out:
# 6

# %%
len(re.findall(r'butterfl\w+', butterflies))
# Out:
# 3

# %% [markdown]
# ### Where are they?

# %%
from spacy.matcher import PhraseMatcher
from spacy import displacy

# %%
matcher = PhraseMatcher(nlp.vocab)
papalotl = nlp(butterflies)
phrase_list = ['butterfly', 'papalotl']
phrase_patterns = [nlp(text) for text in phrase_list]
matcher.add('mariposa', None, *phrase_patterns)
found_matches = matcher(papalotl)
print(found_matches)
# Out:
# [(4860986508236918519, 6, 7), (4860986508236918519, 134, 135), (4860986508236918519, 136, 137)]

# %%
for match_id, start, end in found_matches:
    string_id = nlp.vocab.strings[match_id]
    span = papalotl[start:end]
    print(start, end, span.text)
# Out:
# 6 7 butterfly
# 134 135 papalotl
# 136 137 butterfly

# %% [markdown]
# ### Dependencies

# %%
doc = nlp(sentences[0])

# %%
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="35e31dc2e0d24cd8b78ea5a44ea55565-0" class="displacy" width="3375" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">BUTTERFLY</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Whatever</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">kind</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">butterfly,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">long</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">straight,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">abdomen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">slender,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">neck</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">constricted.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-35e31dc2e0d24cd8b78ea5a44ea55565-0-0" stroke-width="2px" d="M245,352.0 C245,2.0 1275.0,2.0 1275.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-35e31dc2e0d24cd8b78ea5a44ea55565-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-35e31dc2e0d24cd8b78ea5a44ea55565-0-1" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-35e31dc2e0d24cd8b78ea5a44ea55565-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-35e31dc2e0d24cd8b78ea5a44ea55565-0-2" stroke-width="2px" d="M245,352.0 C245,177.0 565.0,177.0 565.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-35e31dc2e0d24cd8b78ea5a44ea55565-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M565.0,354.0 L573.0,342.0 557.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-35e31dc2e0d24cd8b78ea5a44ea55565-0-3" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-35e31dc2e0d24cd8b78ea5a44ea55565-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M735.0,354.0 L743.0,342.0 727.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-35e31dc2e0d24cd8b78ea5a44ea55565-0-4" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-35e31dc2e0d24cd8b78ea5a44ea55565-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M910.0,354.0 L918.0,342.0 902.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3

# %% [markdown]
# ### Part-of-speech tagging

# %%
for i in range(len(sentences)):
    doc = nlp(sentences[i])
    pos = [(w.text, w.pos_) for w in doc]
    for j in pos:
        if j[1] == 'ADJ':
            print(j[0])
# Out:
# long
# straight
# slender
# fuzzy
# twofold
# constant
# different
# fuzzy
# solid
# many
# large
# yellow
# yellow
# fuzzy
# black
# beautiful
# coveted
# desirable
# desirable
# fragile
# firm
# similar
# same
# black
# little
# little
# smoky
# tawny
# smoky
# smoky
# yellow
# smoky
# yellow
# smoky
# yellow
# little
# large
# average
# small
# white
# whitish
# pale
# yellow
# similar
# large
# tiny
# uniform
# pale
# pallid
# yellow
# livid
# light
# blue
# light
# blue
# blue
# large
# small
# Many
# intricate
# wonderful
# intricate
# like
# average
# beautiful
# wonderful
# amaranth
# mature
# ripe
# yellow

# %%
for i in range(len(sentences)):
    doc = nlp(sentences[i])
    pos = [(w.text, w.pos_) for w in doc]
    for j in pos:
        if j[1] == 'VERB':
            print(j[0])
# Out:
# constricted
# winged
# trembles
# beats
# flies
# sucks
# sucks
# comes
# painted
# varicolored
# required
# yellows
# becomcs
# painted
# becomes
# varicolored
# breeds
# becomes
# develops
# flies
# flecked
# varicolored
# TLECOCOZPAPALOTL
# called
# fireyellow
# glows
# glistens
# glows
# glistens
# becomes
# turns
# PAPALOTL
# painted
# sprinkled
# flecked
# painted
# painted
# comes
# takes
# becomes
# varicolored
# sought
# sought
# painted
# called
# become
# named
# become
