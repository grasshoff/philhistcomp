# %% [markdown]
# # The butterflies of the Florentine Codex

# %% [markdown]
# ## Importing packages

# %%
import pandas as pd
import re
import spacy

from spacy.matcher import PhraseMatcher
from spacy import displacy

from spacy.tokens import Span

# %% [markdown]
# ## Sentences with spaCy

# %%
papalotl = open('papalotl.txt')
butterflies = papalotl.read()

# %%
from spacy.lang.en import English

raw_text = butterflies
nlp = English()
nlp.add_pipe(nlp.create_pipe('sentencizer'))
doc = nlp(raw_text)
sentences = [sent.string.strip() for sent in doc.sents]

# %%
sentences[:10]
# Out:
# ['BUTTERFLY\nWhatever the kind of butterfly, it is long and straight, the abdomen is slender, the neck is constricted.',
#  'lt is fuzzy, like fat; winged.',
#  'Its wings are twofold.',
#  'It has arms, it has legs, it has antennae.',
#  'lt is a flyer, a constant flyer, a flutterer, a sucker of the different flowers, and a sucker of liquid.',
#  'It is fuzzy.',
#  'It trembles, it beats its wings together, it constantly flies.',
#  'It sucks, it sucks liquid.',
#  'It is not solid.',
#  'There are many kinds of butterflies.']

# %%
# Get rid of newlines
sentences = [item.replace('\n', " ") for item in sentences]

# %% [markdown]
# ## Creating dataframe

# %%
df = pd.DataFrame(sentences) 
df.columns = ['BUTTERFLY']
df[:10]
# Out:
#                                            BUTTERFLY
# 0  BUTTERFLY Whatever the kind of butterfly, it i...
# 1                     lt is fuzzy, like fat; winged.
# 2                             Its wings are twofold.
# 3         It has arms, it has legs, it has antennae.
# 4  lt is a flyer, a constant flyer, a flutterer, ...
# 5                                       It is fuzzy.
# 6  It trembles, it beats its wings together, it c...
# 7                         It sucks, it sucks liquid.
# 8                                   It is not solid.
# 9               There are many kinds of butterflies.

# %% [markdown]
# ## Tokenization

# %%
# Loading library
nlp = spacy.load('en_core_web_lg')

# %%
doc = nlp(butterflies)

# %%
for token in doc:
    print(token, token.pos_, token.dep_, token.lemma_)
# Out:
# BUTTERFLY PROPN ROOT BUTTERFLY
#
#  SPACE
#
# Whatever DET advcl whatever
# the DET det the
# kind NOUN dobj kind
# of ADP prep of
# butterfly NOUN pobj butterfly
# , PUNCT punct ,
# it PRON nsubj -PRON-
# is AUX ROOT be
# long ADJ acomp long
# and CCONJ cc and
# straight ADJ conj straight
# , PUNCT punct ,
# the DET det the
# abdomen NOUN nsubj abdomen
# is AUX ccomp be
# slender ADJ acomp slender
# , PUNCT punct ,
# the DET det the
# neck NOUN nsubjpass neck
# is AUX auxpass be
# constricted ADJ ROOT constricted
# . PUNCT punct .
# lt PROPN nsubj lt
# is AUX ccomp be
# fuzzy ADJ acomp fuzzy
# , PUNCT punct ,
# like SCONJ prep like
# fat NOUN pobj fat
# ; PUNCT punct ;
# winged ADJ ROOT winged
# . PUNCT punct .
# Its DET poss -PRON-
# wings NOUN nsubj wing
# are AUX ROOT be
# twofold ADJ acomp twofold
# . PUNCT punct .
# It PRON nsubj -PRON-
# has AUX ccomp have
# arms NOUN dobj arm
# , PUNCT punct ,
# it PRON nsubj -PRON-
# has AUX ccomp have
# legs NOUN dobj leg
# , PUNCT punct ,
# it PRON nsubj -PRON-
# has AUX ROOT have
# antennae NOUN dobj antennae
# . PUNCT punct .
# lt PROPN nsubj lt
# is AUX ROOT be
# a DET det a
# flyer NOUN attr flyer
# , PUNCT punct ,
# a DET det a
# constant ADJ amod constant
# flyer NOUN appos flyer
# , PUNCT punct ,
# a DET det a
# flutterer NOUN conj flutterer
# , PUNCT punct ,
# a DET det a
# sucker NOUN appos sucker
# of ADP prep of
# the DET det the
# different ADJ amod different
# flowers NOUN pobj flower
# , PUNCT punct ,
# and CCONJ cc and
# a DET det a
# sucker NOUN conj sucker
# of ADP prep of
# liquid NOUN pobj liquid
# . PUNCT punct .
# It PRON nsubj -PRON-
# is AUX ROOT be
# fuzzy ADJ acomp fuzzy
# . PUNCT punct .
# It PRON nsubj -PRON-
# trembles VERB ccomp tremble
# , PUNCT punct ,
# it PRON nsubj -PRON-
# beats VERB ccomp beat
# its DET poss -PRON-
# wings NOUN dobj wing
# together ADV advmod together
# , PUNCT punct ,
# it PRON nsubj -PRON-
# constantly ADV advmod constantly
# flies VERB ROOT fly
# . PUNCT punct .
# It PRON nsubj -PRON-
# sucks VERB ccomp suck
# , PUNCT punct ,
# it PRON nsubj -PRON-
# sucks VERB ROOT suck
# liquid ADJ dobj liquid
# . PUNCT punct .
# It PRON nsubj -PRON-
# is AUX ROOT be
# not PART neg not
# solid ADJ acomp solid
# . PUNCT punct .
# There PRON expl there
# are AUX ROOT be
# many ADJ amod many
# kinds NOUN attr kind
# of ADP prep of
# butterflies NOUN pobj butterfly
# . PUNCT punct .
#
#
#  SPACE
#
#
# XICALPAPALOTL PROPN ROOT XICALPAPALOTL
# OR CCONJ cc or
# XICALTECONPAPALOTL PROPN conj XICALTECONPAPALOTL
# . PUNCT punct .
# OR CCONJ cc or
# XICALTECON PROPN ROOT XICALTECON
#
#  SPACE
#
# It PRON nsubj -PRON-
# is AUX ROOT be
# somewhat ADV advmod somewhat
# large ADJ acomp large
# . PUNCT punct .
# Its DET poss -PRON-
# name NOUN nsubj name
# comes VERB ccomp come
# from ADP prep from
# xicalli PROPN pobj xicalli
# [ PUNCT punct [
# gourd PROPN compound gourd
# bowl NOUN appos bowl
# ] PUNCT punct ]
# and CCONJ cc and
# papalotl PROPN conj papalotl
# [ PUNCT punct [
# butterfly NOUN appos butterfly
# ] PUNCT punct ]
# , PUNCT punct ,
# because SCONJ mark because
# it PRON nsubj -PRON-
# is AUX advcl be
# yellow ADJ acomp yellow
# , PUNCT punct ,
# it PRON nsubj -PRON-
# is AUX ccomp be
# quite ADV advmod quite
# yellow ADJ acomp yellow
# , PUNCT punct ,
# it PRON nsubj -PRON-
# is AUX ROOT be
# fuzzy ADJ acomp fuzzy
# . PUNCT punct .
# And CCONJ cc and
# it PRON nsubjpass -PRON-
# is AUX auxpass be
# painted VERB ccomp paint
# with ADP prep with
# black ADJ pobj black
# ; PUNCT punct ;
# it PRON nsubj -PRON-
# is AUX auxpass be
# varicolored VERB ROOT varicolore
# . PUNCT punct .
# So ADV advmod so
# it PRON nsubj -PRON-
# is AUX ccomp be
# very ADV advmod very
# beautiful ADJ acomp beautiful
# , PUNCT punct ,
# coveted ADJ conj coveted
# , PUNCT punct ,
# desirable ADJ conj desirable
# , PUNCT punct ,
# constantly ADV advmod constantly
# desirable ADJ conj desirable
# , PUNCT punct ,
# constantly ADV advmod constantly
# required VERB ROOT require
# . PUNCT punct .
# It PRON nsubj -PRON-
# is AUX ROOT be
# fragile ADJ acomp fragile
# . PUNCT punct .
# It PRON nsubj -PRON-
# yellows VERB ROOT yellow
# , PUNCT punct ,
# it PRON nsubj -PRON-
# becomcs PROPN nsubj becomcs
# painted VERB parataxis paint
# , PUNCT punct ,
# it PRON nsubj -PRON-
# becomes VERB ROOT become
# varicolored ADJ acomp varicolored
# . PUNCT punct .
# It PRON nsubj -PRON-
# breeds VERB ROOT breed
# , PUNCT punct ,
# it PRON nsubj -PRON-
# becomes VERB ccomp become
# firm ADJ acomp firm
# , PUNCT punct ,
# it PRON nsubj -PRON-
# develops VERB ccomp develop
# ; PUNCT punct ;
# it PRON nsubj -PRON-
# flies VERB ROOT fly
# constantly ADV advmod constantly
# . PUNCT punct .
#
#
#  SPACE
#
#
# TLILPAPALOTL PROPN ROOT TLILPAPALOTL
#
#  SPACE
#
# It PRON nsubj -PRON-
# is AUX ROOT be
# similar ADJ acomp similar
# to PART prep to
# - PUNCT punct -
# also ADV advmod also
# just ADV advmod just
# the DET det the
# same ADJ npadvmod same
# as SCONJ prep as
# - PUNCT punct -
# the DET det the
# xicalpapalotl PROPN pobj xicalpapalotl
# , PUNCT punct ,
# but CCONJ cc but
# black ADJ amod black
# flecked VERB conj fleck
# with ADP prep with
# white ADJ pobj white
# . PUNCT punct .
# Thus ADV advmod thus
# its DET poss -PRON-
# wings NOUN nsubjpass wing
# are AUX auxpass be
# varicolored VERB ROOT varicolore
# . PUNCT punct .
#
#
#  SPACE
#
#
# TLECOCOZPAPALOTL PROPN ROOT TLECOCOZPAPALOTL
#
#  SPACE
#
# Its DET poss -PRON-
# name NOUN nsubj name
# is AUX ROOT be
# also ADV advmod also
# quappachpapalotl PROPN attr quappachpapalotl
# . PUNCT punct .
# It PRON nsubjpass -PRON-
# is AUX auxpass be
# called VERB ROOT call
# " PUNCT punct "
# fireyellow NOUN oprd fireyellow
# " PUNCT punct "
# because SCONJ mark because
# it PRON nsubj -PRON-
# glows VERB advcl glow
# , PUNCT punct ,
# it PRON nsubj -PRON-
# glistens VERB ROOT glisten
# a DET det a
# little ADJ npadvmod little
# . PUNCT punct .
# lts PROPN compound lts
# body NOUN nsubj body
# is AUX ROOT be
# a DET det a
# little ADJ amod little
# fiery ADJ acomp fiery
# , PUNCT punct ,
# but CCONJ cc but
# it PRON nsubj -PRON-
# is AUX conj be
# smoky ADJ amod smoky
# , PUNCT punct ,
# tawny ADJ acomp tawny
# . PUNCT punct .
# It PRON nsubj -PRON-
# glows VERB ROOT glow
# , PUNCT punct ,
# glistens VERB npadvmod glisten
# , PUNCT punct ,
# glistens VERB dep glisten
# constantly ADV advmod constantly
# . PUNCT punct .
# It PRON nsubj -PRON-
# is AUX ROOT be
# tawny ADJ amod tawny
# , PUNCT punct ,
# smoky ADJ amod smoky
# , PUNCT punct ,
# smoky ADJ amod smoky
# yellow NOUN attr yellow
# . PUNCT punct .
# It PRON nsubj -PRON-
# becomes VERB ccomp become
# smoky ADJ amod smoky
# yellow NOUN attr yellow
# ; PUNCT punct ;
# it PRON nsubj -PRON-
# turns VERB ROOT turn
# smoky ADJ amod smoky
# yellow NOUN dobj yellow
# . PUNCT punct .
#
#
#  SPACE
#
#
# IZTAC PROPN compound IZTAC
# PAPALOTL PROPN ROOT PAPALOTL
#
#  SPACE
#
# Some DET nsubj some
# are AUX ROOT be
# a DET det a
# little ADJ amod little
# large ADJ acomp large
# , PUNCT punct ,
# some DET det some
# average ADJ npadvmod average
# , PUNCT punct ,
# some DET det some
# quite ADV advmod quite
# small ADJ appos small
# . PUNCT punct .
# They PRON nsubj -PRON-
# are AUX ROOT be
# not PART neg not
# really ADV advmod really
# white ADJ acomp white
# , PUNCT punct ,
# only ADV advmod only
# as SCONJ prep as
# whitish ADJ amod whitish
# , PUNCT punct ,
# only ADV advmod only
# as ADV advmod as
# pale ADJ acomp pale
# as SCONJ mark as
# they PRON nsubj -PRON-
# are AUX advcl be
# yellow ADJ acomp yellow
# . PUNCT punct .
#
#
#  SPACE
#
#
# CHIAN PROPN compound CHIAN
# PAPALOTL PROPN ROOT PAPALOTL
# . PUNCT punct .
#
#  SPACE
#
# It PRON nsubj -PRON-
# is AUX ROOT be
# somewhat ADV advmod somewhat
# similar ADJ acomp similar
# to ADP prep to
# the DET det the
# xicalpapalotl PROPN pobj xicalpapalotl
# , PUNCT punct ,
# because SCONJ mark because
# it PRON nsubjpass -PRON-
# is AUX auxpass be
# painted VERB advcl paint
# as SCONJ mark as
# if SCONJ mark if
# sprinkled VERB advcl sprinkle
# with ADP prep with
# chia PROPN pobj chia
# , PUNCT punct ,
# flecked VERB conj fleck
# everywhere ADV advmod everywhere
# on ADP prep on
# its DET poss -PRON-
# body NOUN pobj body
# ; PUNCT punct ;
# and CCONJ cc and
# its DET poss -PRON-
# wings NOUN nsubjpass wing
# are AUX auxpass be
# painted VERB conj paint
# , PUNCT punct ,
# painted VERB conj paint
# with ADP prep with
# a DET det a
# chia PROPN compound chia
# design NOUN pobj design
# . PUNCT punct .
#
#
#  SPACE
#
#
# TEXOPAPALOTL PROPN ROOT TEXOPAPALOTL
#
#  SPACE
#
# Some DET nsubj some
# are AUX ccomp be
# large ADJ acomp large
# , PUNCT punct ,
# some DET det some
# tiny ADJ npadvmod tiny
# ; PUNCT punct ;
# they PRON nsubj -PRON-
# are AUX ROOT be
# not PART neg not
# uniform ADJ acomp uniform
# . PUNCT punct .
# Its DET poss -PRON-
# name NOUN nsubj name
# comes VERB ROOT come
# from ADP prep from
# texotli ADJ amod texotli
# [ PUNCT punct [
# light ADJ compound light
# blue NOUN pobj blue
# ] PUNCT punct ]
# . PUNCT punct .
# But CCONJ cc but
# it PRON nsubj -PRON-
# is AUX ccomp be
# not PART neg not
# really ADV advmod really
# a DET det a
# blue NOUN attr blue
# ; PUNCT punct ;
# it PRON nsubj -PRON-
# is AUX ROOT be
# just ADV advmod just
# so ADV advmod so
# rather ADV advmod rather
# pale ADJ acomp pale
# , PUNCT punct ,
# just ADV advmod just
# so ADV advmod so
# pallid ADJ conj pallid
# , PUNCT punct ,
#
#  SPACE
#
# just ADV advmod just
# so ADV advmod so
# yellow ADJ conj yellow
# as SCONJ mark as
# to PART aux to
# be AUX advcl be
# livid ADJ acomp livid
# . PUNCT punct .
# It PRON nsubj -PRON-
# is AUX ROOT be
# just ADV advmod just
# a DET det a
# light ADJ amod light
# blue ADJ amod blue
# hue NOUN attr hue
# . PUNCT punct .
# It PRON nsubj -PRON-
# takes VERB ccomp take
# on ADP prt on
# a DET det a
# light ADJ amod light
# blue ADJ amod blue
# hue NOUN dobj hue
# ; PUNCT punct ;
# it PRON nsubj -PRON-
# becomes VERB ROOT become
# blue ADJ amod blue
# - PUNCT punct -
# brown ADJ acomp brown
# . PUNCT punct .
#
#
#  SPACE
#
#
# XOCHIPAPALOTL PROPN ROOT XOCHIPAPALOTL
#
#  SPACE
#
# Some DET nsubj some
# are AUX ROOT be
# large ADJ acomp large
# , PUNCT punct ,
# some DET det some
# small ADJ conj small
# . PUNCT punct .
# Many ADJ amod many
# kinds NOUN nsubj kind
# of ADP prep of
# colors NOUN pobj color
# are AUX ROOT be
# on ADP prep on
# them PRON pobj -PRON-
# , PUNCT punct ,
# that SCONJ mark that
# they PRON nsubjpass -PRON-
# are AUX auxpass be
# varicolored VERB advcl varicolore
# , PUNCT punct ,
# much ADV advmod much
# like SCONJ prep like
# flowers NOUN pobj flower
# , PUNCT punct ,
# of ADP prep of
# very ADV advmod very
# intricate ADJ amod intricate
# design NOUN pobj design
# , PUNCT punct ,
# and CCONJ cc and
# truly ADV advmod truly
# sought VERB conj seek
# after ADP prep after
# truly ADV advmod truly
# wonderful ADJ amod wonderful
# . PUNCT punct .
# They PRON nsubj -PRON-
# are AUX ROOT be
# o ADV intj o
# intricate ADJ amod intricate
# design NOUN attr design
# , PUNCT punct ,
# sought VERB conj seek
# after ADP prep after
# , PUNCT punct ,
# flower NOUN npadvmod flower
# - PUNCT punct -
# like ADJ conj like
# . PUNCT punct .
#
#
#  SPACE
#
#
# UAPPAPALOTL PROPN ROOT UAPPAPALOTL
#
#  SPACE
#
# It PRON nsubj -PRON-
# is AUX ccomp be
# of ADP prep of
# average ADJ amod average
# size NOUN pobj size
# ; PUNCT punct ;
# its DET poss -PRON-
# wings NOUN nsubjpass wing
# are AUX auxpass be
# painted VERB ROOT paint
# chili NOUN npadvmod chili
# - PUNCT punct -
# red NOUN oprd red
# . PUNCT punct .
# It PRON nsubj -PRON-
# is AUX ROOT be
# also ADV advmod also
# beautiful ADJ acomp beautiful
# , PUNCT punct ,
# also ADV advmod also
# wonderful ADJ acomp wonderful
# . PUNCT punct .
# Amaranth NOUN compound amaranth
# leaves VERB nsubjpass leave
# or CCONJ cc or
# foliage NOUN conj foliage
# are AUX auxpass be
# also ADV advmod also
# called VERB ROOT call
# uappapalotl PROPN oprd uappapalotl
# when ADV advmod when
# the DET det the
# amaranth NOUN compound amaranth
# leaves VERB nsubj leave
# already ADV advmod already
# become VERB advcl become
# mature ADJ amod mature
# , PUNCT punct ,
# ripe ADJ acomp ripe
# . PUNCT punct .
# Then ADV advmod then
# they PRON nsubjpass -PRON-
# are AUX auxpass be
# named VERB ROOT name
# uappapalotl PROPN oprd uappapalotl
# , PUNCT punct ,
# because SCONJ mark because
# they PRON nsubj -PRON-
# become VERB advcl become
# yellow ADJ acomp yellow
# or CCONJ cc or
# chili NOUN npadvmod chili
# - PUNCT punct -
# red NOUN conj red
# . PUNCT punct .

# %% [markdown]
# ## Showing dependencies

# %%
doc = nlp(sentences[0])

# %%
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="586d783c6fa648e39c74cb2e7d4d63ce-0" class="displacy" width="3375" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">BUTTERFLY</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Whatever</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">kind</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">butterfly,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">long</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">straight,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">abdomen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">slender,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">neck</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">constricted.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-586d783c6fa648e39c74cb2e7d4d63ce-0-0" stroke-width="2px" d="M245,352.0 C245,2.0 1275.0,2.0 1275.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-586d783c6fa648e39c74cb2e7d4d63ce-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-586d783c6fa648e39c74cb2e7d4d63ce-0-1" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-586d783c6fa648e39c74cb2e7d4d63ce-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-586d783c6fa648e39c74cb2e7d4d63ce-0-2" stroke-width="2px" d="M245,352.0 C245,177.0 565.0,177.0 565.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-586d783c6fa648e39c74cb2e7d4d63ce-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M565.0,354.0 L573.0,342.0 557.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-586d783c6fa648e39c74cb2e7d4d63ce-0-3" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-586d783c6fa648e39c74cb2e7d4d63ce-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M735.0,354.0 L743.0,342.0 727.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-586d783c6fa648e39c74cb2e7d4d63ce-0-4" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-586d783c6fa648e39c74cb2e7d4d63ce-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M910.0,354.0 L918.0,342.0 902.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class

# %% [markdown]
# ## Part-of-speech tagging

# %%
for i in range(len(sentences)):
    doc = nlp(sentences[i])
    pos = [(w.text, w.pos_) for w in doc]
    for j in pos:
        if j[1] == 'VERB':
            print(j[0])
# Out:
# trembles
# beats
# flies
# sucks
# sucks
# comes
# painted
# varicolored
# required
# yellows
# painted
# becomes
# breeds
# becomes
# develops
# flies
# flecked
# varicolored
# called
# glows
# glistens
# glows
# glistens
# glistens
# becomes
# turns
# painted
# sprinkled
# flecked
# painted
# painted
# comes
# takes
# becomes
# varicolored
# sought
# sought
# painted
# leaves
# called
# leaves
# become
# named
# become

# %%
for i in range(len(sentences)):
    doc = nlp(sentences[i])
    pos = [(w.text, w.pos_) for w in doc]
    for j in pos:
        if j[1] == 'ADJ':
            print(j[0])
# Out:
# long
# straight
# slender
# constricted
# fuzzy
# winged
# twofold
# constant
# different
# fuzzy
# liquid
# solid
# many
# large
# yellow
# yellow
# fuzzy
# black
# beautiful
# coveted
# desirable
# desirable
# fragile
# varicolored
# firm
# similar
# same
# black
# little
# little
# fiery
# smoky
# tawny
# tawny
# smoky
# smoky
# smoky
# smoky
# little
# large
# average
# small
# white
# whitish
# pale
# yellow
# similar
# large
# tiny
# uniform
# texotli
# light
# pale
# pallid
# yellow
# livid
# light
# blue
# light
# blue
# blue
# brown
# large
# small
# Many
# intricate
# wonderful
# intricate
# like
# average
# beautiful
# wonderful
# Amaranth
# mature
# ripe
# yellow

# %% [markdown]
# ## How many terms?

# %%
len(re.findall('papalotl', butterflies))
# Out:
# 6

# %%
len(re.findall(r'butterfl\w+', butterflies))
# Out:
# 3

# %% [markdown]
# ## Where are they?

# %% [markdown]
# ### The words "butterfly" and "papalotl"

# %%
matcher = PhraseMatcher(nlp.vocab)
papalotl = nlp(butterflies)
phrase_list = ['butterfly', 'papalotl']
phrase_patterns = [nlp(text) for text in phrase_list]
matcher.add('mariposa', None, *phrase_patterns)
found_matches = matcher(papalotl)
print(found_matches)
# Out:
# [(4860986508236918519, 6, 7), (4860986508236918519, 134, 135), (4860986508236918519, 136, 137)]

# %%
for match_id, start, end in found_matches:
    string_id = nlp.vocab.strings[match_id]
    span = papalotl[start:end]
    print(start, end, span.text)
# Out:
# 6 7 butterfly
# 134 135 papalotl
# 136 137 butterfly

# %% [markdown]
# ### Looking for the parts of the butterfly

# %%
doc = nlp(butterflies)

# %%
matcher = PhraseMatcher(nlp.vocab)
papalotl = nlp(butterflies)
phrase_list = ['abdomen', 'neck', 'wings', 'arms', 'legs', 'antennae']
phrase_patterns = [nlp(text) for text in phrase_list]
matcher.add('mariposa', None, *phrase_patterns)
found_matches = matcher(papalotl)

# %%
for match_id, start, end in found_matches:
    string_id = nlp.vocab.strings[match_id]
    span = papalotl[start:end]
    print(start, end, span.text)
# Out:
# 15 16 abdomen
# 20 21 neck
# 34 35 wings
# 40 41 arms
# 44 45 legs
# 48 49 antennae
# 85 86 wings
# 234 235 wings
# 369 370 wings
# 516 517 wings

# %% [markdown]
# ## Adding the body parts of the butterfly as new entities

# %%
def show_ents(doc):
    if doc.ents: 
        for ent in doc.ents:
            print(ent.text+' - '+ent.label_)
    else:
        print('No entity found')

# %%
ORGAN = doc.vocab.strings['ORGAN']

# %%
new_ent = Span(doc, 15, 16, label=ORGAN)
new_ent1 = Span(doc, 20, 21, label=ORGAN) 
new_ent2 = Span(doc, 34, 35, label=ORGAN) 
new_ent3 = Span(doc, 40, 41, label=ORGAN) 
new_ent4 = Span(doc, 44, 45, label=ORGAN) 
new_ent5 = Span(doc, 48, 49, label=ORGAN) 
new_ent6 = Span(doc, 85, 86, label=ORGAN) 
new_ent7 = Span(doc, 234, 235, label=ORGAN) 
new_ent8 = Span(doc, 369, 370, label=ORGAN) 
new_ent9 = Span(doc, 516, 517, label=ORGAN)

# %%
doc.ents = list(doc.ents)+[new_ent]+[new_ent1]+[new_ent2]+[new_ent3]+[new_ent4]+[new_ent5]+[new_ent6]+[new_ent7]+[new_ent8]+[new_ent9]

# %%
show_ents(doc)
# Out:
# abdomen - ORGAN
# neck - ORGAN
# wings - ORGAN
# arms - ORGAN
# legs - ORGAN
# antennae - ORGAN
# wings - ORGAN
# XICALPAPALOTL - ORG
# XICALTECONPAPALOTL - ORG
# XICALTECON - PERSON
# xicalli - PERSON
# TLILPAPALOTL - PERSON
# wings - ORGAN
# TLECOCOZPAPALOTL - ORG
# quappachpapalotl - PERSON
# lts - PERSON
# IZTAC PAPALOTL
#  - PRODUCT
# CHIAN PAPALOTL - PRODUCT
# wings - ORGAN
# TEXOPAPALOTL
#  - LAW
# XOCHIPAPALOTL - PERSON
# UAPPAPALOTL - PERSON
# wings - ORGAN

# %% [markdown]
# ## Highlighting the body parts of the butterfly

# %%
colors = {'ORGAjN': 'purple'}
options = {'ents': ['ORGAN'], 'colors': colors}

# %%
displacy.render(doc, style='ent', options=options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BUTTERFLY</br>Whatever the kind of butterfly, it is long and straight, the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     abdomen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGAN</span>
# </mark>
#  is slender, the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     neck
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGAN</span>
# </mark>
#  is constricted. lt is fuzzy, like fat; winged. Its
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     wings
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGAN</span>
# </mark>
#  are twofold. It has
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     arms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGAN</span>
# </mark>
# , it has
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     legs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGAN</span>
# </mark>
# , it has
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     antennae
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGAN</span>
# </mark>
# . lt is a flyer, a constant flyer, a flutterer, a sucker of the different flowers, and a sucker of liquid. It is fuzzy. It trembles, it beats its
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     wings
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGAN</span>
# </mark>
#  together, it constantly flies. It sucks, it sucks liquid. It is not solid. There are many kinds of butterflies.</br></br>XICALPAPALOTL OR XICALTECONPAPALOTL. OR XICALTECON</br>It is somewhat large. Its name comes from xicalli [gourd bowl] and papalotl [butterfly ], because it is yellow, it is quite yellow, it is fuzzy . And it is painted with black; it is varicolored. So it is very beautiful, coveted, desirable, constantly desirable, constantly required. It is fragile. It yellows, it becomcs painted, it becomes varicolored. It breeds, it becomes firm, it develops; it flies constantly.</br></br>TLILPAPALOTL</br>It is similar to - also just the same as - the xicalpapalotl, but black flecked with white. Thus its
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     wings
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGAN</span>
# </mark>
#  are varicolored.</br></br>TLECOCOZPAPALOTL</br>Its name is also quappachpapalotl. It is called &quot;fireyellow&quot; because it glows, it glistens a little. lts body is a little fiery, but it is smoky, tawny. It glows, glistens, glistens constantly. It is tawny, smoky, smoky yellow. It becomes smoky yellow; it turns smoky yellow.</br></br>IZTAC PAPALOTL
# Some are a little large, some average, some quite small. They are not really white, only as whitish, only as pale as they are yellow.</br></br>CHIAN PAPALOTL.</br>It is somewhat similar to the xicalpapalotl, because it is painted as if sprinkled with chia, flecked everywhere on its body; and its
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     wings
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGAN</span>
# </mark>
#  are painted, painted with a chia design.</br></br>TEXOPAPALOTL
# Some are large, some tiny; they are not uniform. Its name comes from texotli [light blue]. But it is not really a blue; it is just so rather pale, just so pallid,</br>just so yellow as to be livid. It is just a light blue hue. It takes on a light blue hue; it becomes blue-brown.</br></br>XOCHIPAPALOTL</br>Some are large, some small. Many kinds of colors are on them, that they are varicolored, much like flowers, of very intricate design, and truly sought after truly wonderful. They are o intricate design, sought after, flower-like.</br></br>UAPPAPALOTL</br>It is of average size; its
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     wings
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORGAN</span>
# </mark>
#  are painted chili-red. It is also beautiful, also wonderful. Amaranth leaves or foliage are also called uappapalotl when the amaranth leaves already become mature, ripe. Then they are named uappapalotl, because they become yellow or chili-red.</div></span>
